# %% [markdown]
# # IMPORT DEPENDENCIES

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from sklearn.preprocessing import LabelEncoder
import time
import shutil
import pathlib
import itertools
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")
from tensorflow.keras.metrics import Precision, Recall, AUC
from google.colab import runtime
from sklearn.metrics import f1_score, roc_curve, auc, precision_recall_curve

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # LOADING DATA

# %%
batch_size = 16
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
categories = ["Normal","Osteopenia", "Osteoporosis"]

# %%
TfDatasetsPath = '/content/drive/MyDrive/CSEN-240-Project/TfDatasetsFull'
# TfDatasetsPath = 'TfDatasetsFull'

# %%
trainDataset = tf.data.Dataset.load(TfDatasetsPath + "/trainDataset")
validDataset = tf.data.Dataset.load(TfDatasetsPath + "/validDataset")
testDataset = tf.data.Dataset.load(TfDatasetsPath + "/testDataset")

# %%
def augment(image, label):
    image = tf.image.random_brightness(image, max_delta=0.1)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    image = tf.image.random_saturation(image, lower=0.8, upper=1.2)
    image = tf.image.random_hue(image, max_delta=0.1)
    image = tf.image.random_flip_up_down(image)
    image - tf.image.rot90(image, k=tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32))
    return image, label

# %%
augmentedDataset = trainDataset.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
trainDataset = trainDataset.concatenate(augmentedDataset)

# %%
len(trainDataset), len(validDataset), len(testDataset)
# Out:
# (7560, 1080, 540)

# %%
trainDataset = trainDataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)
validDataset = validDataset.batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)
testDataset = testDataset.batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
trainDataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
metrics = [Precision(), Recall(), AUC(), 'accuracy']

# %% [markdown]
# # VGG16 Model

# %%
def createModel(input_shape, num_classes=3, learning_rate=1e-4):
    inputs = tf.keras.layers.Input(shape=input_shape)
    base_model = tf.keras.applications.VGG16(weights="imagenet", input_tensor=inputs, include_top=False)
    base_model.trainable = False
    x = base_model.output
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(512, activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.25)(x)
    x = tf.keras.layers.Dense(256, activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.25)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss="categorical_crossentropy", metrics=metrics)
    return model

# %% [markdown]
# # TRAINING

# %%
input_shape = (224, 224, 3)
model = createModel(input_shape, num_classes=3, learning_rate=1e-4)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 3)                   │             771 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,112,515 (57.65 MB)
#  Trainable params: 396,291 (1.51 MB)
#  Non-trainable params: 14,716,224 (56.14 MB)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_auc', mode='max', patience=8, restore_best_weights=True)

# %%
# Defining The ReduceLRonPlateau Callback
reduceLRCallback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_auc',
    factor=0.8, # How much to improve the learning rate -> LR = LR*factor
    patience=3,
    verbose=1,
    mode='max',
    min_delta=0.0001, # Change in metric below this delta is considered as no change
    cooldown=0, # Number of epochs to wait before resuming normal operation after lr has been improved
    min_lr=0 # Learning Rate won't go below this
)

# %%
history = model.fit(trainDataset,
                        validation_data=validDataset,
                        epochs=250,
                        callbacks=[early_stopping, reduceLRCallback],
                        verbose=1)
# Out:
# Epoch 1/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 85s 128ms/step - accuracy: 0.4890 - auc: 0.6724 - loss: 1.2428 - precision: 0.5053 - recall: 0.4367 - val_accuracy: 0.6009 - val_auc: 0.7863 - val_loss: 0.8674 - val_precision: 0.6708 - val_recall: 0.4981 - learning_rate: 1.0000e-04
# Epoch 2/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.6063 - auc: 0.7937 - loss: 0.9250 - precision: 0.6303 - recall: 0.5661 - val_accuracy: 0.6435 - val_auc: 0.8114 - val_loss: 0.9073 - val_precision: 0.6878 - val_recall: 0.5935 - learning_rate: 1.0000e-04
# Epoch 3/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.6236 - auc: 0.8075 - loss: 0.8795 - precision: 0.6497 - recall: 0.5847 - val_accuracy: 0.7028 - val_auc: 0.8468 - val_loss: 0.7955 - val_precision: 0.7384 - val_recall: 0.6611 - learning_rate: 1.0000e-04
# Epoch 4/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.6431 - auc: 0.8231 - loss: 0.8291 - precision: 0.6710 - recall: 0.5980 - val_accuracy: 0.6657 - val_auc: 0.8340 - val_loss: 0.8346 - val_precision: 0.6947 - val_recall: 0.6194 - learning_rate: 1.0000e-04
# Epoch 5/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.6543 - auc: 0.8341 - loss: 0.8005 - precision: 0.6746 - recall: 0.6080 - val_accuracy: 0.6676 - val_auc: 0.8352 - val_loss: 0.8307 - val_precision: 0.6918 - val_recall: 0.6278 - learning_rate: 1.0000e-04
# Epoch 6/250
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6720 - auc: 0.8485 - loss: 0.7543 - precision: 0.6963 - recall: 0.6324
# Epoch 6: ReduceLROnPlateau reducing learning rate to 7.999999797903001e-05.
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.6720 - auc: 0.8485 - loss: 0.7544 - precision: 0.6963 - recall: 0.6324 - val_accuracy: 0.6722 - val_auc: 0.8433 - val_loss: 0.7885 - val_precision: 0.7039 - val_recall: 0.6250 - learning_rate: 1.0000e-04
# Epoch 7/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.6863 - auc: 0.8576 - loss: 0.7293 - precision: 0.7123 - recall: 0.6415 - val_accuracy: 0.7176 - val_auc: 0.8617 - val_loss: 0.7597 - val_precision: 0.7386 - val_recall: 0.7065 - learning_rate: 8.0000e-05
# Epoch 8/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.6897 - auc: 0.8613 - loss: 0.7225 - precision: 0.7151 - recall: 0.6447 - val_accuracy: 0.7046 - val_auc: 0.8592 - val_loss: 0.7463 - val_precision: 0.7323 - val_recall: 0.6713 - learning_rate: 8.0000e-05
# Epoch 9/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.6920 - auc: 0.8677 - loss: 0.6983 - precision: 0.7180 - recall: 0.6481 - val_accuracy: 0.7111 - val_auc: 0.8655 - val_loss: 0.7419 - val_precision: 0.7366 - val_recall: 0.6759 - learning_rate: 8.0000e-05
# Epoch 10/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7149 - auc: 0.8800 - loss: 0.6660 - precision: 0.7408 - recall: 0.6782 - val_accuracy: 0.6954 - val_auc: 0.8594 - val_loss: 0.7513 - val_precision: 0.7241 - val_recall: 0.6657 - learning_rate: 8.0000e-05
# Epoch 11/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7157 - auc: 0.8821 - loss: 0.6595 - precision: 0.7397 - recall: 0.6749 - val_accuracy: 0.7028 - val_auc: 0.8682 - val_loss: 0.7226 - val_precision: 0.7248 - val_recall: 0.6731 - learning_rate: 8.0000e-05
# Epoch 12/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7103 - auc: 0.8780 - loss: 0.6742 - precision: 0.7383 - recall: 0.6754 - val_accuracy: 0.7130 - val_auc: 0.8708 - val_loss: 0.7302 - val_precision: 0.7388 - val_recall: 0.6889 - learning_rate: 8.0000e-05
# Epoch 13/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7315 - auc: 0.8877 - loss: 0.6432 - precision: 0.7569 - recall: 0.6948 - val_accuracy: 0.7019 - val_auc: 0.8690 - val_loss: 0.7186 - val_precision: 0.7235 - val_recall: 0.6639 - learning_rate: 8.0000e-05
# Epoch 14/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7245 - auc: 0.8920 - loss: 0.6287 - precision: 0.7559 - recall: 0.6888 - val_accuracy: 0.7370 - val_auc: 0.8840 - val_loss: 0.6754 - val_precision: 0.7574 - val_recall: 0.7083 - learning_rate: 8.0000e-05
# Epoch 15/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7458 - auc: 0.9031 - loss: 0.5953 - precision: 0.7726 - recall: 0.7085 - val_accuracy: 0.7231 - val_auc: 0.8737 - val_loss: 0.7210 - val_precision: 0.7377 - val_recall: 0.6926 - learning_rate: 8.0000e-05
# Epoch 16/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7279 - auc: 0.8919 - loss: 0.6307 - precision: 0.7528 - recall: 0.6916 - val_accuracy: 0.7241 - val_auc: 0.8778 - val_loss: 0.6968 - val_precision: 0.7483 - val_recall: 0.6935 - learning_rate: 8.0000e-05
# Epoch 17/250
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7398 - auc: 0.8985 - loss: 0.6088 - precision: 0.7628 - recall: 0.7003
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.399999838322402e-05.
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7398 - auc: 0.8985 - loss: 0.6088 - precision: 0.7628 - recall: 0.7003 - val_accuracy: 0.7259 - val_auc: 0.8801 - val_loss: 0.6854 - val_precision: 0.7500 - val_recall: 0.7000 - learning_rate: 8.0000e-05
# Epoch 18/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7452 - auc: 0.9057 - loss: 0.5844 - precision: 0.7721 - recall: 0.7095 - val_accuracy: 0.7287 - val_auc: 0.8821 - val_loss: 0.6877 - val_precision: 0.7527 - val_recall: 0.7046 - learning_rate: 6.4000e-05
# Epoch 19/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7480 - auc: 0.9106 - loss: 0.5689 - precision: 0.7764 - recall: 0.7164 - val_accuracy: 0.7204 - val_auc: 0.8845 - val_loss: 0.6780 - val_precision: 0.7548 - val_recall: 0.6981 - learning_rate: 6.4000e-05
# Epoch 20/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7639 - auc: 0.9131 - loss: 0.5623 - precision: 0.7842 - recall: 0.7319 - val_accuracy: 0.7296 - val_auc: 0.8870 - val_loss: 0.6635 - val_precision: 0.7520 - val_recall: 0.7019 - learning_rate: 6.4000e-05
# Epoch 21/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7611 - auc: 0.9157 - loss: 0.5557 - precision: 0.7883 - recall: 0.7264 - val_accuracy: 0.7361 - val_auc: 0.8828 - val_loss: 0.6896 - val_precision: 0.7551 - val_recall: 0.7139 - learning_rate: 6.4000e-05
# Epoch 22/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7649 - auc: 0.9164 - loss: 0.5509 - precision: 0.7933 - recall: 0.7307 - val_accuracy: 0.7241 - val_auc: 0.8857 - val_loss: 0.6744 - val_precision: 0.7485 - val_recall: 0.6917 - learning_rate: 6.4000e-05
# Epoch 23/250
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7606 - auc: 0.9155 - loss: 0.5542 - precision: 0.7861 - recall: 0.7281
# Epoch 23: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7606 - auc: 0.9154 - loss: 0.5543 - precision: 0.7861 - recall: 0.7281 - val_accuracy: 0.7380 - val_auc: 0.8853 - val_loss: 0.6926 - val_precision: 0.7573 - val_recall: 0.7167 - learning_rate: 6.4000e-05
# Epoch 24/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7742 - auc: 0.9217 - loss: 0.5352 - precision: 0.7963 - recall: 0.7428 - val_accuracy: 0.7407 - val_auc: 0.8908 - val_loss: 0.6612 - val_precision: 0.7549 - val_recall: 0.7130 - learning_rate: 5.1200e-05
# Epoch 25/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7829 - auc: 0.9261 - loss: 0.5214 - precision: 0.8066 - recall: 0.7486 - val_accuracy: 0.7361 - val_auc: 0.8839 - val_loss: 0.6924 - val_precision: 0.7547 - val_recall: 0.7093 - learning_rate: 5.1200e-05
# Epoch 26/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7783 - auc: 0.9244 - loss: 0.5252 - precision: 0.7998 - recall: 0.7468 - val_accuracy: 0.7491 - val_auc: 0.8931 - val_loss: 0.6589 - val_precision: 0.7634 - val_recall: 0.7231 - learning_rate: 5.1200e-05
# Epoch 27/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7805 - auc: 0.9260 - loss: 0.5203 - precision: 0.8045 - recall: 0.7439 - val_accuracy: 0.7528 - val_auc: 0.8935 - val_loss: 0.6538 - val_precision: 0.7760 - val_recall: 0.7315 - learning_rate: 5.1200e-05
# Epoch 28/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7879 - auc: 0.9289 - loss: 0.5104 - precision: 0.8081 - recall: 0.7539 - val_accuracy: 0.7472 - val_auc: 0.8991 - val_loss: 0.6330 - val_precision: 0.7650 - val_recall: 0.7296 - learning_rate: 5.1200e-05
# Epoch 29/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7886 - auc: 0.9301 - loss: 0.5069 - precision: 0.8167 - recall: 0.7596 - val_accuracy: 0.7472 - val_auc: 0.8959 - val_loss: 0.6489 - val_precision: 0.7710 - val_recall: 0.7231 - learning_rate: 5.1200e-05
# Epoch 30/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7936 - auc: 0.9345 - loss: 0.4890 - precision: 0.8140 - recall: 0.7605 - val_accuracy: 0.7500 - val_auc: 0.8978 - val_loss: 0.6444 - val_precision: 0.7704 - val_recall: 0.7269 - learning_rate: 5.1200e-05
# Epoch 31/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7977 - auc: 0.9338 - loss: 0.4932 - precision: 0.8240 - recall: 0.7685 - val_accuracy: 0.7694 - val_auc: 0.9039 - val_loss: 0.6258 - val_precision: 0.7802 - val_recall: 0.7426 - learning_rate: 5.1200e-05
# Epoch 32/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8012 - auc: 0.9393 - loss: 0.4726 - precision: 0.8225 - recall: 0.7719 - val_accuracy: 0.7509 - val_auc: 0.8969 - val_loss: 0.6458 - val_precision: 0.7667 - val_recall: 0.7241 - learning_rate: 5.1200e-05
# Epoch 33/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.7966 - auc: 0.9369 - loss: 0.4803 - precision: 0.8194 - recall: 0.7688 - val_accuracy: 0.7398 - val_auc: 0.8898 - val_loss: 0.6756 - val_precision: 0.7564 - val_recall: 0.7130 - learning_rate: 5.1200e-05
# Epoch 34/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8057 - auc: 0.9361 - loss: 0.4835 - precision: 0.8243 - recall: 0.7790 - val_accuracy: 0.7519 - val_auc: 0.9061 - val_loss: 0.6031 - val_precision: 0.7773 - val_recall: 0.7306 - learning_rate: 5.1200e-05
# Epoch 35/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8118 - auc: 0.9408 - loss: 0.4664 - precision: 0.8357 - recall: 0.7855 - val_accuracy: 0.7509 - val_auc: 0.9008 - val_loss: 0.6391 - val_precision: 0.7623 - val_recall: 0.7333 - learning_rate: 5.1200e-05
# Epoch 36/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8110 - auc: 0.9411 - loss: 0.4653 - precision: 0.8298 - recall: 0.7847 - val_accuracy: 0.7546 - val_auc: 0.9042 - val_loss: 0.6231 - val_precision: 0.7711 - val_recall: 0.7361 - learning_rate: 5.1200e-05
# Epoch 37/250
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8127 - auc: 0.9421 - loss: 0.4594 - precision: 0.8327 - recall: 0.7862
# Epoch 37: ReduceLROnPlateau reducing learning rate to 4.0960000478662555e-05.
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8126 - auc: 0.9420 - loss: 0.4595 - precision: 0.8326 - recall: 0.7861 - val_accuracy: 0.7519 - val_auc: 0.8957 - val_loss: 0.6637 - val_precision: 0.7661 - val_recall: 0.7278 - learning_rate: 5.1200e-05
# Epoch 38/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8083 - auc: 0.9415 - loss: 0.4638 - precision: 0.8281 - recall: 0.7766 - val_accuracy: 0.7537 - val_auc: 0.9007 - val_loss: 0.6426 - val_precision: 0.7807 - val_recall: 0.7417 - learning_rate: 4.0960e-05
# Epoch 39/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8147 - auc: 0.9435 - loss: 0.4550 - precision: 0.8302 - recall: 0.7906 - val_accuracy: 0.7528 - val_auc: 0.8995 - val_loss: 0.6496 - val_precision: 0.7754 - val_recall: 0.7352 - learning_rate: 4.0960e-05
# Epoch 40/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8086 - auc: 0.9443 - loss: 0.4520 - precision: 0.8282 - recall: 0.7849 - val_accuracy: 0.7556 - val_auc: 0.9070 - val_loss: 0.6118 - val_precision: 0.7745 - val_recall: 0.7315 - learning_rate: 4.0960e-05
# Epoch 41/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8157 - auc: 0.9456 - loss: 0.4480 - precision: 0.8380 - recall: 0.7917 - val_accuracy: 0.7463 - val_auc: 0.9005 - val_loss: 0.6458 - val_precision: 0.7607 - val_recall: 0.7269 - learning_rate: 4.0960e-05
# Epoch 42/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8146 - auc: 0.9446 - loss: 0.4511 - precision: 0.8324 - recall: 0.7879 - val_accuracy: 0.7556 - val_auc: 0.9019 - val_loss: 0.6309 - val_precision: 0.7698 - val_recall: 0.7278 - learning_rate: 4.0960e-05
# Epoch 43/250
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8246 - auc: 0.9491 - loss: 0.4340 - precision: 0.8453 - recall: 0.7972
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.2767999800853435e-05.
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8245 - auc: 0.9491 - loss: 0.4341 - precision: 0.8452 - recall: 0.7971 - val_accuracy: 0.7565 - val_auc: 0.9045 - val_loss: 0.6261 - val_precision: 0.7711 - val_recall: 0.7361 - learning_rate: 4.0960e-05
# Epoch 44/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8259 - auc: 0.9501 - loss: 0.4277 - precision: 0.8473 - recall: 0.7999 - val_accuracy: 0.7556 - val_auc: 0.9035 - val_loss: 0.6289 - val_precision: 0.7764 - val_recall: 0.7361 - learning_rate: 3.2768e-05
# Epoch 45/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8257 - auc: 0.9493 - loss: 0.4314 - precision: 0.8444 - recall: 0.8048 - val_accuracy: 0.7426 - val_auc: 0.9017 - val_loss: 0.6370 - val_precision: 0.7672 - val_recall: 0.7231 - learning_rate: 3.2768e-05
# Epoch 46/250
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8259 - auc: 0.9526 - loss: 0.4184 - precision: 0.8467 - recall: 0.8032
# Epoch 46: ReduceLROnPlateau reducing learning rate to 2.6214399258606137e-05.
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8258 - auc: 0.9525 - loss: 0.4185 - precision: 0.8466 - recall: 0.8032 - val_accuracy: 0.7528 - val_auc: 0.9025 - val_loss: 0.6355 - val_precision: 0.7738 - val_recall: 0.7287 - learning_rate: 3.2768e-05
# Epoch 47/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 47ms/step - accuracy: 0.8280 - auc: 0.9508 - loss: 0.4261 - precision: 0.8453 - recall: 0.8071 - val_accuracy: 0.7593 - val_auc: 0.9076 - val_loss: 0.6117 - val_precision: 0.7855 - val_recall: 0.7426 - learning_rate: 2.6214e-05
# Epoch 48/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8331 - auc: 0.9536 - loss: 0.4146 - precision: 0.8572 - recall: 0.8079 - val_accuracy: 0.7574 - val_auc: 0.9055 - val_loss: 0.6232 - val_precision: 0.7757 - val_recall: 0.7398 - learning_rate: 2.6214e-05
# Epoch 49/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8276 - auc: 0.9527 - loss: 0.4179 - precision: 0.8483 - recall: 0.8077 - val_accuracy: 0.7491 - val_auc: 0.9030 - val_loss: 0.6397 - val_precision: 0.7645 - val_recall: 0.7306 - learning_rate: 2.6214e-05
# Epoch 50/250
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8401 - auc: 0.9557 - loss: 0.4036 - precision: 0.8589 - recall: 0.8172
# Epoch 50: ReduceLROnPlateau reducing learning rate to 2.09715188248083e-05.
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8400 - auc: 0.9557 - loss: 0.4038 - precision: 0.8589 - recall: 0.8171 - val_accuracy: 0.7454 - val_auc: 0.9013 - val_loss: 0.6446 - val_precision: 0.7621 - val_recall: 0.7269 - learning_rate: 2.6214e-05
# Epoch 51/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8373 - auc: 0.9547 - loss: 0.4078 - precision: 0.8543 - recall: 0.8126 - val_accuracy: 0.7565 - val_auc: 0.9060 - val_loss: 0.6306 - val_precision: 0.7753 - val_recall: 0.7380 - learning_rate: 2.0972e-05
# Epoch 52/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8429 - auc: 0.9551 - loss: 0.4075 - precision: 0.8637 - recall: 0.8215 - val_accuracy: 0.7537 - val_auc: 0.9038 - val_loss: 0.6389 - val_precision: 0.7676 - val_recall: 0.7278 - learning_rate: 2.0972e-05
# Epoch 53/250
# 472/473 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8330 - auc: 0.9526 - loss: 0.4172 - precision: 0.8477 - recall: 0.8115
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.6777214477770033e-05.
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8330 - auc: 0.9526 - loss: 0.4173 - precision: 0.8476 - recall: 0.8115 - val_accuracy: 0.7583 - val_auc: 0.9063 - val_loss: 0.6238 - val_precision: 0.7801 - val_recall: 0.7389 - learning_rate: 2.0972e-05
# Epoch 54/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8296 - auc: 0.9509 - loss: 0.4234 - precision: 0.8480 - recall: 0.8036 - val_accuracy: 0.7611 - val_auc: 0.9062 - val_loss: 0.6249 - val_precision: 0.7796 - val_recall: 0.7435 - learning_rate: 1.6777e-05
# Epoch 55/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.8439 - auc: 0.9567 - loss: 0.3998 - precision: 0.8622 - recall: 0.8226 - val_accuracy: 0.7528 - val_auc: 0.9060 - val_loss: 0.6275 - val_precision: 0.7699 - val_recall: 0.7343 - learning_rate: 1.6777e-05

# %% [markdown]
# # FINE-TUNING

# %%
for layer in model.layers[1:-8]:
    layer.trainable = True

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=5e-6), loss="categorical_crossentropy", metrics=metrics)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 3)                   │             771 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,112,515 (57.65 MB)
#  Trainable params: 15,110,979 (57.64 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
history = model.fit( trainDataset,
                         validation_data=validDataset,
                         epochs=250,
                         callbacks=[early_stopping, reduceLRCallback],
                         verbose=1)
# Out:
# Epoch 1/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 104s 164ms/step - accuracy: 0.7809 - auc: 0.9211 - loss: 0.5083 - precision: 0.7910 - recall: 0.7518 - val_accuracy: 0.7093 - val_auc: 0.8785 - val_loss: 0.8087 - val_precision: 0.7265 - val_recall: 0.7009 - learning_rate: 5.0000e-06
# Epoch 2/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.8186 - auc: 0.9454 - loss: 0.4463 - precision: 0.8353 - recall: 0.7919 - val_accuracy: 0.6481 - val_auc: 0.8428 - val_loss: 0.9668 - val_precision: 0.6628 - val_recall: 0.6352 - learning_rate: 5.0000e-06
# Epoch 3/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.8379 - auc: 0.9528 - loss: 0.4145 - precision: 0.8529 - recall: 0.8214 - val_accuracy: 0.7759 - val_auc: 0.9094 - val_loss: 0.6286 - val_precision: 0.7977 - val_recall: 0.7630 - learning_rate: 5.0000e-06
# Epoch 4/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.8687 - auc: 0.9675 - loss: 0.3461 - precision: 0.8826 - recall: 0.8497 - val_accuracy: 0.7407 - val_auc: 0.9009 - val_loss: 0.7206 - val_precision: 0.7524 - val_recall: 0.7315 - learning_rate: 5.0000e-06
# Epoch 5/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.8718 - auc: 0.9690 - loss: 0.3362 - precision: 0.8831 - recall: 0.8558 - val_accuracy: 0.7537 - val_auc: 0.9017 - val_loss: 0.6612 - val_precision: 0.7657 - val_recall: 0.7352 - learning_rate: 5.0000e-06
# Epoch 6/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.8866 - auc: 0.9760 - loss: 0.2988 - precision: 0.8956 - recall: 0.8732 - val_accuracy: 0.7759 - val_auc: 0.9188 - val_loss: 0.6161 - val_precision: 0.7888 - val_recall: 0.7676 - learning_rate: 5.0000e-06
# Epoch 7/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.8869 - auc: 0.9767 - loss: 0.2931 - precision: 0.8981 - recall: 0.8751 - val_accuracy: 0.7306 - val_auc: 0.9079 - val_loss: 0.6435 - val_precision: 0.7400 - val_recall: 0.7222 - learning_rate: 5.0000e-06
# Epoch 8/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.8986 - auc: 0.9809 - loss: 0.2661 - precision: 0.9092 - recall: 0.8873 - val_accuracy: 0.7685 - val_auc: 0.9201 - val_loss: 0.6265 - val_precision: 0.7829 - val_recall: 0.7611 - learning_rate: 5.0000e-06
# Epoch 9/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.8938 - auc: 0.9794 - loss: 0.2738 - precision: 0.9016 - recall: 0.8836 - val_accuracy: 0.7139 - val_auc: 0.8755 - val_loss: 0.8484 - val_precision: 0.7240 - val_recall: 0.7093 - learning_rate: 5.0000e-06
# Epoch 10/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.9050 - auc: 0.9834 - loss: 0.2469 - precision: 0.9112 - recall: 0.8945 - val_accuracy: 0.7370 - val_auc: 0.9022 - val_loss: 0.7357 - val_precision: 0.7413 - val_recall: 0.7296 - learning_rate: 5.0000e-06
# Epoch 11/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.9117 - auc: 0.9844 - loss: 0.2401 - precision: 0.9191 - recall: 0.8994 - val_accuracy: 0.7704 - val_auc: 0.9236 - val_loss: 0.6150 - val_precision: 0.7806 - val_recall: 0.7611 - learning_rate: 5.0000e-06
# Epoch 12/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.9203 - auc: 0.9869 - loss: 0.2181 - precision: 0.9268 - recall: 0.9133 - val_accuracy: 0.7685 - val_auc: 0.9222 - val_loss: 0.6111 - val_precision: 0.7809 - val_recall: 0.7556 - learning_rate: 5.0000e-06
# Epoch 13/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.9237 - auc: 0.9889 - loss: 0.2035 - precision: 0.9328 - recall: 0.9168 - val_accuracy: 0.7315 - val_auc: 0.8892 - val_loss: 0.8107 - val_precision: 0.7401 - val_recall: 0.7250 - learning_rate: 5.0000e-06
# Epoch 14/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.9232 - auc: 0.9888 - loss: 0.2005 - precision: 0.9294 - recall: 0.9177 - val_accuracy: 0.8000 - val_auc: 0.9335 - val_loss: 0.5517 - val_precision: 0.8070 - val_recall: 0.7935 - learning_rate: 5.0000e-06
# Epoch 15/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.9336 - auc: 0.9905 - loss: 0.1890 - precision: 0.9373 - recall: 0.9289 - val_accuracy: 0.7546 - val_auc: 0.9118 - val_loss: 0.6825 - val_precision: 0.7615 - val_recall: 0.7481 - learning_rate: 5.0000e-06
# Epoch 16/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.9314 - auc: 0.9897 - loss: 0.1907 - precision: 0.9365 - recall: 0.9254 - val_accuracy: 0.7759 - val_auc: 0.9198 - val_loss: 0.6269 - val_precision: 0.7852 - val_recall: 0.7648 - learning_rate: 5.0000e-06
# Epoch 17/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9383 - auc: 0.9918 - loss: 0.1721 - precision: 0.9423 - recall: 0.9339
# Epoch 17: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.9383 - auc: 0.9918 - loss: 0.1722 - precision: 0.9422 - recall: 0.9338 - val_accuracy: 0.7704 - val_auc: 0.9146 - val_loss: 0.6692 - val_precision: 0.7772 - val_recall: 0.7685 - learning_rate: 5.0000e-06
# Epoch 18/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.9350 - auc: 0.9919 - loss: 0.1699 - precision: 0.9394 - recall: 0.9316 - val_accuracy: 0.7722 - val_auc: 0.9198 - val_loss: 0.6272 - val_precision: 0.7837 - val_recall: 0.7648 - learning_rate: 4.0000e-06
# Epoch 19/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.9442 - auc: 0.9934 - loss: 0.1550 - precision: 0.9470 - recall: 0.9412 - val_accuracy: 0.7593 - val_auc: 0.9101 - val_loss: 0.7129 - val_precision: 0.7713 - val_recall: 0.7556 - learning_rate: 4.0000e-06
# Epoch 20/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9484 - auc: 0.9950 - loss: 0.1359 - precision: 0.9520 - recall: 0.9445
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.199999991920777e-06.
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.9484 - auc: 0.9950 - loss: 0.1360 - precision: 0.9520 - recall: 0.9445 - val_accuracy: 0.7769 - val_auc: 0.9182 - val_loss: 0.7255 - val_precision: 0.7807 - val_recall: 0.7713 - learning_rate: 4.0000e-06
# Epoch 21/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.9527 - auc: 0.9936 - loss: 0.1411 - precision: 0.9554 - recall: 0.9481 - val_accuracy: 0.7713 - val_auc: 0.9242 - val_loss: 0.6704 - val_precision: 0.7785 - val_recall: 0.7648 - learning_rate: 3.2000e-06
# Epoch 22/250
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 65s 136ms/step - accuracy: 0.9464 - auc: 0.9938 - loss: 0.1459 - precision: 0.9495 - recall: 0.9430 - val_accuracy: 0.7907 - val_auc: 0.9289 - val_loss: 0.6205 - val_precision: 0.7959 - val_recall: 0.7833 - learning_rate: 3.2000e-06

# %% [markdown]
# # PLOTS

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %% [markdown]
# # PR Curve

# %%
valid_labels = []
for xBatch, yBatch in validDataset:
    valid_labels.extend(np.argmax(yBatch, axis=1))
predictions = model.predict(validDataset)
predicted_classes = np.argmax(predictions, axis=1)
yTrue = np.eye(3)[valid_labels]
yPred = predictions
thresholds = {}
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step

# %%
for class_idx in range(3):
    precision, recall, thresholds_pr = precision_recall_curve(yTrue[:, class_idx], yPred[:, class_idx])

    f1_scores = 2 * (precision * recall) / (precision + recall)

    optimal_threshold_pr = thresholds_pr[np.argmax(f1_scores)]
    thresholds[class_idx] = optimal_threshold_pr

    plt.plot(recall, precision, label=f'Class {class_idx} (area = {auc(recall, precision):.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve for each class')
plt.legend(loc="best")
plt.show()

# %%
print("Optimal thresholds for each class (based on maximum F1 score):")
for class_idx, threshold in thresholds.items():
    print(f"Class {class_idx}: {threshold}")
# Out:
# Optimal thresholds for each class (based on maximum F1 score):
# Class 0: 0.39287200570106506
# Class 1: 0.3082839846611023
# Class 2: 0.5649396181106567

# %% [markdown]
# # TESTING

# %%
def customPredict(yPred, thresholds):
    predictions = np.zeros_like(yPred)
    for i in thresholds.keys():
        threshold = thresholds[i]
        predictions[:, i] = (yPred[:, i] >= threshold).astype(int)
    predictions = np.argmax(predictions * yPred, axis=1)
    return predictions

# %%
test_labels = []
for xBatch, yBatch in testDataset:
    test_labels.extend(np.argmax(yBatch, axis=1))
predictions = customPredict(model.predict(testDataset), thresholds)
# predictions = np.argmax(model.predict(testDataset), axis=1)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step

# %%
report = classification_report(test_labels, predictions, target_names=categories)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.81      0.83      0.82       180
#   Osteopenia       0.84      0.88      0.86       180
# Osteoporosis       0.84      0.78      0.81       180
#
#     accuracy                           0.83       540
#    macro avg       0.83      0.83      0.83       540
# weighted avg       0.83      0.83      0.83       540

# %%
conf_matrix = confusion_matrix(test_labels, predictions)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=categories,
            yticklabels=categories)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
# Out:
# Text(95.72222222222221, 0.5, 'True Label')

# %%
model.save('/content/drive/MyDrive/CSEN-240-Project/Models/VGG16-16.h5')
model.save('/content/drive/MyDrive/CSEN-240-Project/KerasModels/VGG16-16.keras')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
runtime.unassign()
