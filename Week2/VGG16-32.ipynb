# %% [markdown]
# # IMPORT DEPENDENCIES

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from sklearn.preprocessing import LabelEncoder
import time
import shutil
import pathlib
import itertools
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")
from tensorflow.keras.metrics import Precision, Recall, AUC
from google.colab import runtime
from sklearn.metrics import f1_score, roc_curve, auc, precision_recall_curve

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # LOADING DATA

# %%
batch_size = 32
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
categories = ["Normal","Osteopenia", "Osteoporosis"]

# %%
TfDatasetsPath = '/content/drive/MyDrive/CSEN-240-Project/TfDatasetsFull'
# TfDatasetsPath = 'TfDatasetsFull'

# %%
trainDataset = tf.data.Dataset.load(TfDatasetsPath + "/trainDataset")
validDataset = tf.data.Dataset.load(TfDatasetsPath + "/validDataset")
testDataset = tf.data.Dataset.load(TfDatasetsPath + "/testDataset")

# %%
def augment(image, label):
    image = tf.image.random_brightness(image, max_delta=0.1)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    image = tf.image.random_saturation(image, lower=0.8, upper=1.2)
    image = tf.image.random_hue(image, max_delta=0.1)
    image = tf.image.random_flip_up_down(image)
    image - tf.image.rot90(image, k=tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32))
    return image, label

# %%
augmentedDataset = trainDataset.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
trainDataset = trainDataset.concatenate(augmentedDataset)

# %%
len(trainDataset), len(validDataset), len(testDataset)
# Out:
# (7560, 1080, 540)

# %%
trainDataset = trainDataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)
validDataset = validDataset.batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)
testDataset = testDataset.batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
trainDataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
metrics = [Precision(), Recall(), AUC(), 'accuracy']

# %% [markdown]
# # VGG16 Model

# %%
def createModel(input_shape, num_classes=3, learning_rate=1e-4):
    inputs = tf.keras.layers.Input(shape=input_shape)
    base_model = tf.keras.applications.VGG16(weights="imagenet", input_tensor=inputs, include_top=False)
    base_model.trainable = False
    x = base_model.output
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(512, activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.25)(x)
    x = tf.keras.layers.Dense(256, activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.25)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss="categorical_crossentropy", metrics=metrics)
    return model

# %% [markdown]
# # TRAINING

# %%
input_shape = (224, 224, 3)
model = createModel(input_shape, num_classes=3, learning_rate=1e-4)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 3)                   │             771 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,112,515 (57.65 MB)
#  Trainable params: 396,291 (1.51 MB)
#  Non-trainable params: 14,716,224 (56.14 MB)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_auc', mode='max', patience=8, restore_best_weights=True)

# %%
# Defining The ReduceLRonPlateau Callback
reduceLRCallback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_auc',
    factor=0.8, # How much to improve the learning rate -> LR = LR*factor
    patience=3,
    verbose=1,
    mode='max',
    min_delta=0.0001, # Change in metric below this delta is considered as no change
    cooldown=0, # Number of epochs to wait before resuming normal operation after lr has been improved
    min_lr=0 # Learning Rate won't go below this
)

# %%
history = model.fit(trainDataset,
                        validation_data=validDataset,
                        epochs=250,
                        callbacks=[early_stopping, reduceLRCallback],
                        verbose=1)
# Out:
# Epoch 1/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 82s 227ms/step - accuracy: 0.4925 - auc: 0.6759 - loss: 1.2680 - precision: 0.5127 - recall: 0.4503 - val_accuracy: 0.5843 - val_auc: 0.7641 - val_loss: 0.9606 - val_precision: 0.7885 - val_recall: 0.1657 - learning_rate: 1.0000e-04
# Epoch 2/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 86ms/step - accuracy: 0.6115 - auc: 0.7979 - loss: 0.9195 - precision: 0.6345 - recall: 0.5723 - val_accuracy: 0.6204 - val_auc: 0.8051 - val_loss: 0.8513 - val_precision: 0.6964 - val_recall: 0.5139 - learning_rate: 1.0000e-04
# Epoch 3/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.6286 - auc: 0.8129 - loss: 0.8813 - precision: 0.6518 - recall: 0.5889 - val_accuracy: 0.6583 - val_auc: 0.8314 - val_loss: 0.8290 - val_precision: 0.6934 - val_recall: 0.5926 - learning_rate: 1.0000e-04
# Epoch 4/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.6457 - auc: 0.8299 - loss: 0.8235 - precision: 0.6684 - recall: 0.6108 - val_accuracy: 0.6574 - val_auc: 0.8338 - val_loss: 0.8270 - val_precision: 0.7079 - val_recall: 0.6259 - learning_rate: 1.0000e-04
# Epoch 5/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.6727 - auc: 0.8468 - loss: 0.7693 - precision: 0.6978 - recall: 0.6335 - val_accuracy: 0.6500 - val_auc: 0.8294 - val_loss: 0.8608 - val_precision: 0.6806 - val_recall: 0.6194 - learning_rate: 1.0000e-04
# Epoch 6/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.6717 - auc: 0.8507 - loss: 0.7606 - precision: 0.7005 - recall: 0.6356 - val_accuracy: 0.6889 - val_auc: 0.8446 - val_loss: 0.8010 - val_precision: 0.7211 - val_recall: 0.6463 - learning_rate: 1.0000e-04
# Epoch 7/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.6883 - auc: 0.8595 - loss: 0.7329 - precision: 0.7110 - recall: 0.6493 - val_accuracy: 0.6750 - val_auc: 0.8442 - val_loss: 0.7960 - val_precision: 0.7064 - val_recall: 0.6370 - learning_rate: 1.0000e-04
# Epoch 8/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.6920 - auc: 0.8621 - loss: 0.7199 - precision: 0.7176 - recall: 0.6526 - val_accuracy: 0.6991 - val_auc: 0.8538 - val_loss: 0.7879 - val_precision: 0.7382 - val_recall: 0.6685 - learning_rate: 1.0000e-04
# Epoch 9/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.7065 - auc: 0.8756 - loss: 0.6853 - precision: 0.7353 - recall: 0.6684 - val_accuracy: 0.6889 - val_auc: 0.8598 - val_loss: 0.7515 - val_precision: 0.7277 - val_recall: 0.6657 - learning_rate: 1.0000e-04
# Epoch 10/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7067 - auc: 0.8740 - loss: 0.6881 - precision: 0.7268 - recall: 0.6653 - val_accuracy: 0.7120 - val_auc: 0.8666 - val_loss: 0.7313 - val_precision: 0.7431 - val_recall: 0.6750 - learning_rate: 1.0000e-04
# Epoch 11/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7206 - auc: 0.8839 - loss: 0.6536 - precision: 0.7442 - recall: 0.6781 - val_accuracy: 0.6852 - val_auc: 0.8576 - val_loss: 0.7615 - val_precision: 0.7049 - val_recall: 0.6546 - learning_rate: 1.0000e-04
# Epoch 12/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7303 - auc: 0.8922 - loss: 0.6304 - precision: 0.7537 - recall: 0.6907 - val_accuracy: 0.7065 - val_auc: 0.8679 - val_loss: 0.7279 - val_precision: 0.7439 - val_recall: 0.6778 - learning_rate: 1.0000e-04
# Epoch 13/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7244 - auc: 0.8879 - loss: 0.6425 - precision: 0.7466 - recall: 0.6888 - val_accuracy: 0.7083 - val_auc: 0.8665 - val_loss: 0.7459 - val_precision: 0.7383 - val_recall: 0.6870 - learning_rate: 1.0000e-04
# Epoch 14/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7381 - auc: 0.8964 - loss: 0.6183 - precision: 0.7650 - recall: 0.6997 - val_accuracy: 0.7167 - val_auc: 0.8733 - val_loss: 0.7034 - val_precision: 0.7460 - val_recall: 0.6935 - learning_rate: 1.0000e-04
# Epoch 15/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7460 - auc: 0.9047 - loss: 0.5910 - precision: 0.7688 - recall: 0.7076 - val_accuracy: 0.7176 - val_auc: 0.8746 - val_loss: 0.7047 - val_precision: 0.7447 - val_recall: 0.6889 - learning_rate: 1.0000e-04
# Epoch 16/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7520 - auc: 0.9067 - loss: 0.5831 - precision: 0.7761 - recall: 0.7163 - val_accuracy: 0.7019 - val_auc: 0.8675 - val_loss: 0.7241 - val_precision: 0.7259 - val_recall: 0.6620 - learning_rate: 1.0000e-04
# Epoch 17/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7562 - auc: 0.9066 - loss: 0.5851 - precision: 0.7762 - recall: 0.7188 - val_accuracy: 0.7269 - val_auc: 0.8808 - val_loss: 0.6922 - val_precision: 0.7550 - val_recall: 0.6991 - learning_rate: 1.0000e-04
# Epoch 18/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7479 - auc: 0.9088 - loss: 0.5784 - precision: 0.7718 - recall: 0.7156 - val_accuracy: 0.7213 - val_auc: 0.8781 - val_loss: 0.7027 - val_precision: 0.7465 - val_recall: 0.6926 - learning_rate: 1.0000e-04
# Epoch 19/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7597 - auc: 0.9159 - loss: 0.5538 - precision: 0.7805 - recall: 0.7345 - val_accuracy: 0.7370 - val_auc: 0.8876 - val_loss: 0.6654 - val_precision: 0.7597 - val_recall: 0.7083 - learning_rate: 1.0000e-04
# Epoch 20/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7679 - auc: 0.9182 - loss: 0.5431 - precision: 0.7913 - recall: 0.7368 - val_accuracy: 0.7056 - val_auc: 0.8726 - val_loss: 0.7222 - val_precision: 0.7267 - val_recall: 0.6796 - learning_rate: 1.0000e-04
# Epoch 21/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7827 - auc: 0.9267 - loss: 0.5184 - precision: 0.8074 - recall: 0.7501 - val_accuracy: 0.7139 - val_auc: 0.8737 - val_loss: 0.7261 - val_precision: 0.7403 - val_recall: 0.6889 - learning_rate: 1.0000e-04
# Epoch 22/250
# 236/237 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7740 - auc: 0.9221 - loss: 0.5327 - precision: 0.7950 - recall: 0.7407
# Epoch 22: ReduceLROnPlateau reducing learning rate to 7.999999797903001e-05.
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7739 - auc: 0.9221 - loss: 0.5328 - precision: 0.7949 - recall: 0.7406 - val_accuracy: 0.7306 - val_auc: 0.8851 - val_loss: 0.6806 - val_precision: 0.7527 - val_recall: 0.7046 - learning_rate: 1.0000e-04
# Epoch 23/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7809 - auc: 0.9266 - loss: 0.5174 - precision: 0.8097 - recall: 0.7552 - val_accuracy: 0.7407 - val_auc: 0.8921 - val_loss: 0.6505 - val_precision: 0.7660 - val_recall: 0.7213 - learning_rate: 8.0000e-05
# Epoch 24/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.
# 236/237 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8531 - auc: 0.9662 - loss: 0.3514 - precision: 0.8678 - recall: 0.8361
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.6777214477770033e-05.
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.8530 - auc: 0.9662 - loss: 0.3517 - precision: 0.8677 - recall: 0.8360 - val_accuracy: 0.7583 - val_auc: 0.9125 - val_loss: 0.6022 - val_precision: 0.7736 - val_recall: 0.7435 - learning_rate: 2.0972e-05
# Epoch 57/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.8545 - auc: 0.9654 - loss: 0.3581 - precision: 0.8715 - recall: 0.8346 - val_accuracy: 0.7722 - val_auc: 0.9145 - val_loss: 0.5979 - val_precision: 0.7824 - val_recall: 0.7491 - learning_rate: 1.6777e-05
# Epoch 58/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.8575 - auc: 0.9664 - loss: 0.3522 - precision: 0.8736 - recall: 0.8374 - val_accuracy: 0.7685 - val_auc: 0.9122 - val_loss: 0.6076 - val_precision: 0.7836 - val_recall: 0.7509 - learning_rate: 1.6777e-05
# Epoch 59/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.8538 - auc: 0.9646 - loss: 0.3604 - precision: 0.8669 - recall: 0.8356 - val_accuracy: 0.7648 - val_auc: 0.9091 - val_loss: 0.6238 - val_precision: 0.7763 - val_recall: 0.7454 - learning_rate: 1.6777e-05
# Epoch 60/250
# 236/237 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8563 - auc: 0.9670 - loss: 0.3485 - precision: 0.8752 - recall: 0.8396
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.3421771291177721e-05.
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.8562 - auc: 0.9670 - loss: 0.3487 - precision: 0.8752 - recall: 0.8395 - val_accuracy: 0.7704 - val_auc: 0.9122 - val_loss: 0.6115 - val_precision: 0.7825 - val_recall: 0.7528 - learning_rate: 1.6777e-05
# Epoch 61/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.8675 - auc: 0.9704 - loss: 0.3329 - precision: 0.8850 - recall: 0.8494 - val_accuracy: 0.7630 - val_auc: 0.9109 - val_loss: 0.6141 - val_precision: 0.7768 - val_recall: 0.7444 - learning_rate: 1.3422e-05
# Epoch 62/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.8589 - auc: 0.9662 - loss: 0.3522 - precision: 0.8731 - recall: 0.8402 - val_accuracy: 0.7667 - val_auc: 0.9111 - val_loss: 0.6128 - val_precision: 0.7782 - val_recall: 0.7472 - learning_rate: 1.3422e-05
# Epoch 63/250
# 236/237 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8664 - auc: 0.9675 - loss: 0.3471 - precision: 0.8802 - recall: 0.8429
# Epoch 63: ReduceLROnPlateau reducing learning rate to 1.0737417323980481e-05.
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.8663 - auc: 0.9675 - loss: 0.3474 - precision: 0.8801 - recall: 0.8428 - val_accuracy: 0.7657 - val_auc: 0.9102 - val_loss: 0.6189 - val_precision: 0.7798 - val_recall: 0.7509 - learning_rate: 1.3422e-05
# Epoch 64/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.8624 - auc: 0.9669 - loss: 0.3479 - precision: 0.8776 - recall: 0.8433 - val_accuracy: 0.7685 - val_auc: 0.9130 - val_loss: 0.6078 - val_precision: 0.7801 - val_recall: 0.7491 - learning_rate: 1.0737e-05
# Epoch 65/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.8640 - auc: 0.9691 - loss: 0.3375 - precision: 0.8803 - recall: 0.8470 - val_accuracy: 0.7694 - val_auc: 0.9125 - val_loss: 0.6104 - val_precision: 0.7832 - val_recall: 0.7528 - learning_rate: 1.0737e-05

# %% [markdown]
# # FINE-TUNING

# %%
for layer in model.layers[1:-8]:
    layer.trainable = True

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=5e-6), loss="categorical_crossentropy", metrics=metrics)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 3)                   │             771 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,112,515 (57.65 MB)
#  Trainable params: 15,110,979 (57.64 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
history = model.fit( trainDataset,
                         validation_data=validDataset,
                         epochs=250,
                         callbacks=[early_stopping, reduceLRCallback],
                         verbose=1)
# Out:
# Epoch 1/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 112s 321ms/step - accuracy: 0.8354 - auc: 0.9406 - loss: 0.4092 - precision: 0.8297 - recall: 0.7934 - val_accuracy: 0.6917 - val_auc: 0.8698 - val_loss: 0.8409 - val_precision: 0.7009 - val_recall: 0.6769 - learning_rate: 5.0000e-06
# Epoch 2/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 257ms/step - accuracy: 0.8480 - auc: 0.9623 - loss: 0.3683 - precision: 0.8614 - recall: 0.8319 - val_accuracy: 0.7148 - val_auc: 0.8834 - val_loss: 0.7609 - val_precision: 0.7259 - val_recall: 0.7037 - learning_rate: 5.0000e-06
# Epoch 3/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.8705 - auc: 0.9712 - loss: 0.3240 - precision: 0.8818 - recall: 0.8562 - val_accuracy: 0.7444 - val_auc: 0.8977 - val_loss: 0.6853 - val_precision: 0.7538 - val_recall: 0.7315 - learning_rate: 5.0000e-06
# Epoch 4/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.8829 - auc: 0.9756 - loss: 0.2999 - precision: 0.8962 - recall: 0.8691 - val_accuracy: 0.7648 - val_auc: 0.9107 - val_loss: 0.6609 - val_precision: 0.7786 - val_recall: 0.7556 - learning_rate: 5.0000e-06
# Epoch 5/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.8926 - auc: 0.9788 - loss: 0.2791 - precision: 0.9021 - recall: 0.8802 - val_accuracy: 0.7407 - val_auc: 0.8976 - val_loss: 0.6927 - val_precision: 0.7483 - val_recall: 0.7269 - learning_rate: 5.0000e-06
# Epoch 6/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.8944 - auc: 0.9799 - loss: 0.2732 - precision: 0.9042 - recall: 0.8816 - val_accuracy: 0.7324 - val_auc: 0.8964 - val_loss: 0.7150 - val_precision: 0.7424 - val_recall: 0.7204 - learning_rate: 5.0000e-06
# Epoch 7/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8987 - auc: 0.9815 - loss: 0.2621 - precision: 0.9075 - recall: 0.8860
# Epoch 7: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.8987 - auc: 0.9815 - loss: 0.2622 - precision: 0.9075 - recall: 0.8860 - val_accuracy: 0.7361 - val_auc: 0.8914 - val_loss: 0.7516 - val_precision: 0.7469 - val_recall: 0.7213 - learning_rate: 5.0000e-06
# Epoch 8/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.9108 - auc: 0.9861 - loss: 0.2309 - precision: 0.9190 - recall: 0.8998 - val_accuracy: 0.7556 - val_auc: 0.8949 - val_loss: 0.7294 - val_precision: 0.7656 - val_recall: 0.7500 - learning_rate: 4.0000e-06
# Epoch 9/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.9193 - auc: 0.9885 - loss: 0.2123 - precision: 0.9245 - recall: 0.9077 - val_accuracy: 0.7630 - val_auc: 0.9107 - val_loss: 0.6826 - val_precision: 0.7692 - val_recall: 0.7500 - learning_rate: 4.0000e-06
# Epoch 10/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.
250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.9503 - auc: 0.9949 - loss: 0.1357 - precision: 0.9526 - recall: 0.9475 - val_accuracy: 0.7380 - val_auc: 0.8978 - val_loss: 0.7773 - val_precision: 0.7469 - val_recall: 0.7324 - learning_rate: 3.2000e-06
# Epoch 22/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 257ms/step - accuracy: 0.9565 - auc: 0.9953 - loss: 0.1311 - precision: 0.9588 - recall: 0.9534 - val_accuracy: 0.7611 - val_auc: 0.9198 - val_loss: 0.6610 - val_precision: 0.7689 - val_recall: 0.7546 - learning_rate: 3.2000e-06
# Epoch 23/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9508 - auc: 0.9950 - loss: 0.1349 - precision: 0.9532 - recall: 0.9470
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.5600000299164097e-06.
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.9508 - auc: 0.9950 - loss: 0.1350 - precision: 0.9532 - recall: 0.9469 - val_accuracy: 0.7815 - val_auc: 0.9158 - val_loss: 0.6876 - val_precision: 0.7828 - val_recall: 0.7741 - learning_rate: 3.2000e-06
# Epoch 24/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.9577 - auc: 0.9960 - loss: 0.1208 - precision: 0.9596 - recall: 0.9547 - val_accuracy: 0.7713 - val_auc: 0.9199 - val_loss: 0.6853 - val_precision: 0.7805 - val_recall: 0.7639 - learning_rate: 2.5600e-06
# Epoch 25/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 257ms/step - accuracy: 0.9583 - auc: 0.9965 - loss: 0.1147 - precision: 0.9594 - recall: 0.9558 - val_accuracy: 0.7806 - val_auc: 0.9330 - val_loss: 0.6014 - val_precision: 0.7885 - val_recall: 0.7769 - learning_rate: 2.5600e-06
# Epoch 26/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.9595 - auc: 0.9969 - loss: 0.1107 - precision: 0.9619 - recall: 0.9566 - val_accuracy: 0.7731 - val_auc: 0.9210 - val_loss: 0.6922 - val_precision: 0.7788 - val_recall: 0.7694 - learning_rate: 2.5600e-06
# Epoch 27/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.9510 - auc: 0.9961 - loss: 0.1201 - precision: 0.9542 - recall: 0.9495 - val_accuracy: 0.7769 - val_auc: 0.9203 - val_loss: 0.6899 - val_precision: 0.7807 - val_recall: 0.7713 - learning_rate: 2.5600e-06
# Epoch 28/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9562 - auc: 0.9962 - loss: 0.1173 - precision: 0.9597 - recall: 0.9549
# Epoch 28: ReduceLROnPlateau reducing learning rate to 2.0479999875533397e-06.
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.9562 - auc: 0.9962 - loss: 0.1174 - precision: 0.9597 - recall: 0.9549 - val_accuracy: 0.7694 - val_auc: 0.9228 - val_loss: 0.6770 - val_precision: 0.7754 - val_recall: 0.7639 - learning_rate: 2.5600e-06
# Epoch 29/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.9644 - auc: 0.9975 - loss: 0.0993 - precision: 0.9661 - recall: 0.9627 - val_accuracy: 0.7694 - val_auc: 0.9212 - val_loss: 0.6827 - val_precision: 0.7784 - val_recall: 0.7676 - learning_rate: 2.0480e-06
# Epoch 30/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.9633 - auc: 0.9969 - loss: 0.1066 - precision: 0.9653 - recall: 0.9609 - val_accuracy: 0.7769 - val_auc: 0.9249 - val_loss: 0.6476 - val_precision: 0.7814 - val_recall: 0.7713 - learning_rate: 2.0480e-06
# Epoch 31/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9626 - auc: 0.9973 - loss: 0.1017 - precision: 0.9643 - recall: 0.9602
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.6383999536628835e-06.
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.9626 - auc: 0.9973 - loss: 0.1017 - precision: 0.9643 - recall: 0.9601 - val_accuracy: 0.7824 - val_auc: 0.9287 - val_loss: 0.6383 - val_precision: 0.7904 - val_recall: 0.7787 - learning_rate: 2.0480e-06
# Epoch 32/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.9638 - auc: 0.9972 - loss: 0.1026 - precision: 0.9654 - recall: 0.9619 - val_accuracy: 0.7667 - val_auc: 0.9217 - val_loss: 0.6740 - val_precision: 0.7744 - val_recall: 0.7630 - learning_rate: 1.6384e-06
# Epoch 33/250
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 62s 256ms/step - accuracy: 0.9642 - auc: 0.9979 - loss: 0.0930 - precision: 0.9667 - recall: 0.9625 - val_accuracy: 0.7843 - val_auc: 0.9263 - val_loss: 0.6594 - val_precision: 0.7897 - val_recall: 0.7787 - learning_rate: 1.6384e-06

# %% [markdown]
# # PLOTS

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %% [markdown]
# # PR Curve

# %%
valid_labels = []
for xBatch, yBatch in validDataset:
    valid_labels.extend(np.argmax(yBatch, axis=1))
predictions = model.predict(validDataset)
predicted_classes = np.argmax(predictions, axis=1)
yTrue = np.eye(3)[valid_labels]
yPred = predictions
thresholds = {}
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step

# %%
for class_idx in range(3):
    precision, recall, thresholds_pr = precision_recall_curve(yTrue[:, class_idx], yPred[:, class_idx])

    f1_scores = 2 * (precision * recall) / (precision + recall)

    optimal_threshold_pr = thresholds_pr[np.argmax(f1_scores)]
    thresholds[class_idx] = optimal_threshold_pr

    plt.plot(recall, precision, label=f'Class {class_idx} (area = {auc(recall, precision):.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve for each class')
plt.legend(loc="best")
plt.show()

# %%
print("Optimal thresholds for each class (based on maximum F1 score):")
for class_idx, threshold in thresholds.items():
    print(f"Class {class_idx}: {threshold}")
# Out:
# Optimal thresholds for each class (based on maximum F1 score):
# Class 0: 0.35104691982269287
# Class 1: 0.15078146755695343
# Class 2: 0.8181604146957397

# %% [markdown]
# # TESTING

# %%
def customPredict(yPred, thresholds):
    predictions = np.zeros_like(yPred)
    for i in thresholds.keys():
        threshold = thresholds[i]
        predictions[:, i] = (yPred[:, i] >= threshold).astype(int)
    predictions = np.argmax(predictions * yPred, axis=1)
    return predictions

# %%
test_labels = []
for xBatch, yBatch in testDataset:
    test_labels.extend(np.argmax(yBatch, axis=1))
predictions = customPredict(model.predict(testDataset), thresholds)
# predictions = np.argmax(model.predict(testDataset), axis=1)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 660ms/step

# %%
report = classification_report(test_labels, predictions, target_names=categories)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.81      0.89      0.85       180
#   Osteopenia       0.85      0.91      0.88       180
# Osteoporosis       0.87      0.73      0.79       180
#
#     accuracy                           0.84       540
#    macro avg       0.84      0.84      0.84       540
# weighted avg       0.84      0.84      0.84       540

# %%
conf_matrix = confusion_matrix(test_labels, predictions)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=categories,
            yticklabels=categories)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
# Out:
# Text(95.72222222222221, 0.5, 'True Label')

# %%
model.save('/content/drive/MyDrive/CSEN-240-Project/Models/VGG16.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
runtime.unassign()
