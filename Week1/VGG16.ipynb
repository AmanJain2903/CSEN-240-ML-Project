# %% [markdown]
# # IMPORT DEPENDENCIES

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from sklearn.preprocessing import LabelEncoder
import time
import shutil
import pathlib
import itertools
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")
from tensorflow.keras.metrics import Precision, Recall, AUC
from google.colab import runtime
from sklearn.metrics import f1_score, roc_curve, auc, precision_recall_curve
import keras_hub

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # LOADING DATA

# %%
batch_size = 32
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
categories = ["Normal","Osteopenia", "Osteoporosis"]

# %%
TfDatasetsPath = '/content/drive/MyDrive/CSEN-240-Project/TfDatasets'
# TfDatasetsPath = 'TfDatasets'

# %%
trainDataset = tf.data.Dataset.load(TfDatasetsPath + "/trainDataset")
validDataset = tf.data.Dataset.load(TfDatasetsPath + "/validDataset")
testDataset = tf.data.Dataset.load(TfDatasetsPath + "/testDataset")

# %%
def augment(image, label):
    image = tf.image.random_brightness(image, max_delta=0.1)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    image = tf.image.random_saturation(image, lower=0.8, upper=1.2)
    image = tf.image.random_hue(image, max_delta=0.1)
    image = tf.image.random_flip_up_down(image)
    image - tf.image.rot90(image, k=tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32))
    return image, label

# %%
augmentedDataset = trainDataset.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
trainDataset = trainDataset.concatenate(augmentedDataset)

# %%
len(trainDataset), len(validDataset), len(testDataset)
# Out:
# (6048, 378, 378)

# %%
trainDataset = trainDataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)
validDataset = validDataset.batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)
testDataset = testDataset.batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
trainDataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
metrics = [Precision(), Recall(), AUC(), 'accuracy']

# %% [markdown]
# # VGG16 Model

# %%
def createModel(input_shape, num_classes=3, learning_rate=1e-4):
    inputs = tf.keras.layers.Input(shape=input_shape)
    base_model = tf.keras.applications.VGG16(weights="imagenet", input_tensor=inputs, include_top=False)
    base_model.trainable = False
    x = base_model.output
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(512, activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.25)(x)
    x = tf.keras.layers.Dense(256, activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.25)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss="categorical_crossentropy", metrics=metrics)
    return model

# %% [markdown]
# # TRAINING

# %%
input_shape = (224, 224, 3)
model = createModel(input_shape, num_classes=3, learning_rate=1e-4)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 3)                   │             771 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,112,515 (57.65 MB)
#  Trainable params: 396,291 (1.51 MB)
#  Non-trainable params: 14,716,224 (56.14 MB)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_auc', mode='max', patience=8, restore_best_weights=True)

# %%
# Defining The ReduceLRonPlateau Callback
reduceLRCallback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_auc',
    factor=0.8, # How much to improve the learning rate -> LR = LR*factor
    patience=3,
    verbose=1,
    mode='max',
    min_delta=0.0001, # Change in metric below this delta is considered as no change
    cooldown=0, # Number of epochs to wait before resuming normal operation after lr has been improved
    min_lr=0 # Learning Rate won't go below this
)

# %%
history = model.fit(trainDataset,
                        validation_data=validDataset,
                        epochs=250,
                        callbacks=[early_stopping, reduceLRCallback],
                        verbose=1)
# Out:
# Epoch 1/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 63s 190ms/step - accuracy: 0.5173 - auc: 0.7046 - loss: 1.1796 - precision: 0.5310 - recall: 0.4677 - val_accuracy: 0.4233 - val_auc: 0.6550 - val_loss: 1.0126 - val_precision: 0.6075 - val_recall: 0.1720 - learning_rate: 1.0000e-04
# Epoch 2/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 16s 81ms/step - accuracy: 0.6063 - auc: 0.7917 - loss: 0.9539 - precision: 0.6254 - recall: 0.5646 - val_accuracy: 0.5926 - val_auc: 0.8032 - val_loss: 0.8249 - val_precision: 0.7124 - val_recall: 0.4259 - learning_rate: 1.0000e-04
# Epoch 3/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 16s 82ms/step - accuracy: 0.6385 - auc: 0.8186 - loss: 0.8731 - precision: 0.6632 - recall: 0.6062 - val_accuracy: 0.6534 - val_auc: 0.8334 - val_loss: 0.7684 - val_precision: 0.6867 - val_recall: 0.6032 - learning_rate: 1.0000e-04
# Epoch 4/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 83ms/step - accuracy: 0.6530 - auc: 0.8337 - loss: 0.8179 - precision: 0.6697 - recall: 0.6128 - val_accuracy: 0.6323 - val_auc: 0.8322 - val_loss: 0.7931 - val_precision: 0.6384 - val_recall: 0.5979 - learning_rate: 1.0000e-04
# Epoch 5/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - accuracy: 0.6574 - auc: 0.8402 - loss: 0.7934 - precision: 0.6803 - recall: 0.6170 - val_accuracy: 0.6376 - val_auc: 0.8381 - val_loss: 0.7689 - val_precision: 0.6559 - val_recall: 0.5899 - learning_rate: 1.0000e-04
# Epoch 6/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.6701 - auc: 0.8448 - loss: 0.7864 - precision: 0.6925 - recall: 0.6335 - val_accuracy: 0.6296 - val_auc: 0.8438 - val_loss: 0.7719 - val_precision: 0.6580 - val_recall: 0.6005 - learning_rate: 1.0000e-04
# Epoch 7/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.6854 - auc: 0.8559 - loss: 0.7493 - precision: 0.7052 - recall: 0.6495 - val_accuracy: 0.6746 - val_auc: 0.8555 - val_loss: 0.7475 - val_precision: 0.6854 - val_recall: 0.6455 - learning_rate: 1.0000e-04
# Epoch 8/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.6863 - auc: 0.8609 - loss: 0.7324 - precision: 0.7137 - recall: 0.6521 - val_accuracy: 0.6614 - val_auc: 0.8604 - val_loss: 0.7374 - val_precision: 0.6980 - val_recall: 0.6481 - learning_rate: 1.0000e-04
# Epoch 9/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 83ms/step - accuracy: 0.7144 - auc: 0.8786 - loss: 0.6794 - precision: 0.7428 - recall: 0.6804 - val_accuracy: 0.6164 - val_auc: 0.8425 - val_loss: 0.7739 - val_precision: 0.6500 - val_recall: 0.5847 - learning_rate: 1.0000e-04
# Epoch 10/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.6997 - auc: 0.8721 - loss: 0.6981 - precision: 0.7266 - recall: 0.6611 - val_accuracy: 0.6746 - val_auc: 0.8690 - val_loss: 0.6995 - val_precision: 0.6997 - val_recall: 0.6534 - learning_rate: 1.0000e-04
# Epoch 11/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7169 - auc: 0.8827 - loss: 0.6642 - precision: 0.7403 - recall: 0.6830 - val_accuracy: 0.6614 - val_auc: 0.8532 - val_loss: 0.7419 - val_precision: 0.6939 - val_recall: 0.6296 - learning_rate: 1.0000e-04
# Epoch 12/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7131 - auc: 0.8854 - loss: 0.6541 - precision: 0.7366 - recall: 0.6764 - val_accuracy: 0.6984 - val_auc: 0.8711 - val_loss: 0.7014 - val_precision: 0.7075 - val_recall: 0.6720 - learning_rate: 1.0000e-04
# Epoch 13/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7160 - auc: 0.8887 - loss: 0.6423 - precision: 0.7390 - recall: 0.6857 - val_accuracy: 0.6958 - val_auc: 0.8743 - val_loss: 0.6821 - val_precision: 0.7106 - val_recall: 0.6561 - learning_rate: 1.0000e-04
# Epoch 14/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7329 - auc: 0.8913 - loss: 0.6345 - precision: 0.7523 - recall: 0.6929 - val_accuracy: 0.7063 - val_auc: 0.8762 - val_loss: 0.6788 - val_precision: 0.7197 - val_recall: 0.6587 - learning_rate: 1.0000e-04
# Epoch 15/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7252 - auc: 0.8963 - loss: 0.6176 - precision: 0.7507 - recall: 0.6894 - val_accuracy: 0.6905 - val_auc: 0.8791 - val_loss: 0.6654 - val_precision: 0.7208 - val_recall: 0.6693 - learning_rate: 1.0000e-04
# Epoch 16/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - accuracy: 0.7447 - auc: 0.9025 - loss: 0.6014 - precision: 0.7671 - recall: 0.7141 - val_accuracy: 0.7063 - val_auc: 0.8826 - val_loss: 0.6667 - val_precision: 0.7244 - val_recall: 0.6746 - learning_rate: 1.0000e-04
# Epoch 17/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7638 - auc: 0.9071 - loss: 0.5845 - precision: 0.7806 - recall: 0.7316 - val_accuracy: 0.7169 - val_auc: 0.8755 - val_loss: 0.7002 - val_precision: 0.7337 - val_recall: 0.6852 - learning_rate: 1.0000e-04
# Epoch 18/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7485 - auc: 0.9099 - loss: 0.5734 - precision: 0.7692 - recall: 0.7209 - val_accuracy: 0.7090 - val_auc: 0.8773 - val_loss: 0.6744 - val_precision: 0.7257 - val_recall: 0.6720 - learning_rate: 1.0000e-04
# Epoch 19/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7628 - auc: 0.9129 - loss: 0.5614 - precision: 0.7833 - recall: 0.7278 - val_accuracy: 0.7169 - val_auc: 0.8865 - val_loss: 0.6487 - val_precision: 0.7360 - val_recall: 0.6931 - learning_rate: 1.0000e-04
# Epoch 20/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7685 - auc: 0.9202 - loss: 0.5400 - precision: 0.7919 - recall: 0.7392 - val_accuracy: 0.7169 - val_auc: 0.8856 - val_loss: 0.6587 - val_precision: 0.7296 - val_recall: 0.6852 - learning_rate: 1.0000e-04
# Epoch 21/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7662 - auc: 0.9146 - loss: 0.5576 - precision: 0.7909 - recall: 0.7302 - val_accuracy: 0.7169 - val_auc: 0.8880 - val_loss: 0.6611 - val_precision: 0.7275 - val_recall: 0.6852 - learning_rate: 1.0000e-04
# Epoch 22/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7753 - auc: 0.9214 - loss: 0.5357 - precision: 0.7956 - recall: 0.7451 - val_accuracy: 0.6984 - val_auc: 0.8852 - val_loss: 0.6650 - val_precision: 0.7183 - val_recall: 0.6746 - learning_rate: 1.0000e-04
# Epoch 23/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7793 - auc: 0.9214 - loss: 0.5367 - precision: 0.7968 - recall: 0.7449 - val_accuracy: 0.7116 - val_auc: 0.8875 - val_loss: 0.6464 - val_precision: 0.7386 - val_recall: 0.6878 - learning_rate: 1.0000e-04
# Epoch 24/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7832 - auc: 0.9269 - loss: 0.5158 - precision: 0.8017 - recall: 0.7543
# Epoch 24: ReduceLROnPlateau reducing learning rate to 7.999999797903001e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7832 - auc: 0.9269 - loss: 0.5159 - precision: 0.8016 - recall: 0.7542 - val_accuracy: 0.7011 - val_auc: 0.8831 - val_loss: 0.6650 - val_precision: 0.7297 - val_recall: 0.6640 - learning_rate: 1.0000e-04
# Epoch 25/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7900 - auc: 0.9294 - loss: 0.5050 - precision: 0.8084 - recall: 0.7574 - val_accuracy: 0.7196 - val_auc: 0.8874 - val_loss: 0.6526 - val_precision: 0.7379 - val_recall: 0.6852 - learning_rate: 8.0000e-05
# Epoch 26/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7848 - auc: 0.9316 - loss: 0.5002 - precision: 0.8100 - recall: 0.7606 - val_accuracy: 0.7196 - val_auc: 0.8928 - val_loss: 0.6380 - val_precision: 0.7331 - val_recall: 0.6905 - learning_rate: 8.0000e-05
# Epoch 27/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - accuracy: 0.7926 - auc: 0.9337 - loss: 0.4905 - precision: 0.8163 - recall: 0.7722 - val_accuracy: 0.7249 - val_auc: 0.8972 - val_loss: 0.6235 - val_precision: 0.7415 - val_recall: 0.6905 - learning_rate: 8.0000e-05
# Epoch 28/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7932 - auc: 0.9349 - loss: 0.4862 - precision: 0.8110 - recall: 0.7672 - val_accuracy: 0.7090 - val_auc: 0.8931 - val_loss: 0.6467 - val_precision: 0.7322 - val_recall: 0.6799 - learning_rate: 8.0000e-05
# Epoch 29/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8056 - auc: 0.9397 - loss: 0.4688 - precision: 0.8279 - recall: 0.7813 - val_accuracy: 0.7222 - val_auc: 0.8925 - val_loss: 0.6360 - val_precision: 0.7396 - val_recall: 0.7063 - learning_rate: 8.0000e-05
# Epoch 30/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8067 - auc: 0.9417 - loss: 0.4613 - precision: 0.8278 - recall: 0.7778
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.399999838322402e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8067 - auc: 0.9417 - loss: 0.4614 - precision: 0.8277 - recall: 0.7778 - val_accuracy: 0.7249 - val_auc: 0.8911 - val_loss: 0.6455 - val_precision: 0.7471 - val_recall: 0.6878 - learning_rate: 8.0000e-05
# Epoch 31/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8054 - auc: 0.9404 - loss: 0.4656 - precision: 0.8223 - recall: 0.7817 - val_accuracy: 0.7407 - val_auc: 0.9010 - val_loss: 0.6188 - val_precision: 0.7556 - val_recall: 0.7116 - learning_rate: 6.4000e-05
# Epoch 32/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8124 - auc: 0.9438 - loss: 0.4522 - precision: 0.8312 - recall: 0.7930 - val_accuracy: 0.7381 - val_auc: 0.8974 - val_loss: 0.6266 - val_precision: 0.7514 - val_recall: 0.7037 - learning_rate: 6.4000e-05
# Epoch 33/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8148 - auc: 0.9455 - loss: 0.4454 - precision: 0.8350 - recall: 0.7932 - val_accuracy: 0.7196 - val_auc: 0.8980 - val_loss: 0.6219 - val_precision: 0.7352 - val_recall: 0.6905 - learning_rate: 6.4000e-05
# Epoch 34/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8234 - auc: 0.9488 - loss: 0.4346 - precision: 0.8437 - recall: 0.7975 - val_accuracy: 0.7275 - val_auc: 0.9047 - val_loss: 0.5998 - val_precision: 0.7444 - val_recall: 0.7011 - learning_rate: 6.4000e-05
# Epoch 35/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8244 - auc: 0.9475 - loss: 0.4373 - precision: 0.8419 - recall: 0.8013 - val_accuracy: 0.7407 - val_auc: 0.9050 - val_loss: 0.6056 - val_precision: 0.7583 - val_recall: 0.7222 - learning_rate: 6.4000e-05
# Epoch 36/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8176 - auc: 0.9465 - loss: 0.4415 - precision: 0.8358 - recall: 0.7930 - val_accuracy: 0.7513 - val_auc: 0.9071 - val_loss: 0.5915 - val_precision: 0.7699 - val_recall: 0.7169 - learning_rate: 6.4000e-05
# Epoch 37/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - accuracy: 0.8233 - auc: 0.9508 - loss: 0.4245 - precision: 0.8412 - recall: 0.7960 - val_accuracy: 0.7434 - val_auc: 0.9059 - val_loss: 0.6075 - val_precision: 0.7597 - val_recall: 0.7275 - learning_rate: 6.4000e-05
# Epoch 38/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8247 - auc: 0.9521 - loss: 0.4193 - precision: 0.8429 - recall: 0.8059 - val_accuracy: 0.7434 - val_auc: 0.9035 - val_loss: 0.6165 - val_precision: 0.7669 - val_recall: 0.7222 - learning_rate: 6.4000e-05
# Epoch 39/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8319 - auc: 0.9544 - loss: 0.4074 - precision: 0.8490 - recall: 0.8063
# Epoch 39: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8318 - auc: 0.9544 - loss: 0.4076 - precision: 0.8489 - recall: 0.8062 - val_accuracy: 0.7249 - val_auc: 0.9011 - val_loss: 0.6177 - val_precision: 0.7430 - val_recall: 0.7037 - learning_rate: 6.4000e-05
# Epoch 40/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8253 - auc: 0.9532 - loss: 0.4143 - precision: 0.8511 - recall: 0.8062 - val_accuracy: 0.7619 - val_auc: 0.9056 - val_loss: 0.6049 - val_precision: 0.7718 - val_recall: 0.7249 - learning_rate: 5.1200e-05
# Epoch 41/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8284 - auc: 0.9509 - loss: 0.4228 - precision: 0.8494 - recall: 0.8089 - val_accuracy: 0.7487 - val_auc: 0.8981 - val_loss: 0.6231 - val_precision: 0.7599 - val_recall: 0.7116 - learning_rate: 5.1200e-05
# Epoch 42/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8349 - auc: 0.9568 - loss: 0.3980 - precision: 0.8529 - recall: 0.8097 - val_accuracy: 0.7513 - val_auc: 0.9096 - val_loss: 0.5881 - val_precision: 0.7614 - val_recall: 0.7090 - learning_rate: 5.1200e-05
# Epoch 43/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8389 - auc: 0.9556 - loss: 0.4027 - precision: 0.8519 - recall: 0.8182 - val_accuracy: 0.7566 - val_auc: 0.9046 - val_loss: 0.6127 - val_precision: 0.7718 - val_recall: 0.7249 - learning_rate: 5.1200e-05
# Epoch 44/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8478 - auc: 0.9599 - loss: 0.3850 - precision: 0.8626 - recall: 0.8222 - val_accuracy: 0.7407 - val_auc: 0.9062 - val_loss: 0.6060 - val_precision: 0.7684 - val_recall: 0.7196 - learning_rate: 5.1200e-05
# Epoch 45/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8378 - auc: 0.9599 - loss: 0.3833 - precision: 0.8586 - recall: 0.8212
# Epoch 45: ReduceLROnPlateau reducing learning rate to 4.0960000478662555e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8377 - auc: 0.9598 - loss: 0.3834 - precision: 0.8585 - recall: 0.8211 - val_accuracy: 0.7354 - val_auc: 0.9034 - val_loss: 0.6209 - val_precision: 0.7620 - val_recall: 0.7116 - learning_rate: 5.1200e-05
# Epoch 46/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8428 - auc: 0.9581 - loss: 0.3949 - precision: 0.8584 - recall: 0.8241 - val_accuracy: 0.7593 - val_auc: 0.9063 - val_loss: 0.6065 - val_precision: 0.7790 - val_recall: 0.7460 - learning_rate: 4.0960e-05
# Epoch 47/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8511 - auc: 0.9622 - loss: 0.3737 - precision: 0.8678 - recall: 0.8335 - val_accuracy: 0.7566 - val_auc: 0.9088 - val_loss: 0.5991 - val_precision: 0.7639 - val_recall: 0.7275 - learning_rate: 4.0960e-05
# Epoch 48/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8565 - auc: 0.9618 - loss: 0.3743 - precision: 0.8762 - recall: 0.8390
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.2767999800853435e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8564 - auc: 0.9618 - loss: 0.3745 - precision: 0.8761 - recall: 0.8389 - val_accuracy: 0.7672 - val_auc: 0.9062 - val_loss: 0.6112 - val_precision: 0.7709 - val_recall: 0.7302 - learning_rate: 4.0960e-05
# Epoch 49/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8495 - auc: 0.9625 - loss: 0.3725 - precision: 0.8676 - recall: 0.8274 - val_accuracy: 0.7646 - val_auc: 0.9128 - val_loss: 0.5847 - val_precision: 0.7799 - val_recall: 0.7407 - learning_rate: 3.2768e-05
# Epoch 50/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - accuracy: 0.8507 - auc: 0.9597 - loss: 0.3836 - precision: 0.8643 - recall: 0.8293 - val_accuracy: 0.7487 - val_auc: 0.9100 - val_loss: 0.5900 - val_precision: 0.7639 - val_recall: 0.7275 - learning_rate: 3.2768e-05
# Epoch 51/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8601 - auc: 0.9645 - loss: 0.3625 - precision: 0.8746 - recall: 0.8358 - val_accuracy: 0.7540 - val_auc: 0.9114 - val_loss: 0.5943 - val_precision: 0.7729 - val_recall: 0.7381 - learning_rate: 3.2768e-05
# Epoch 52/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8530 - auc: 0.9659 - loss: 0.3548 - precision: 0.8669 - recall: 0.8381
# Epoch 52: ReduceLROnPlateau reducing learning rate to 2.6214399258606137e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8529 - auc: 0.9658 - loss: 0.3550 - precision: 0.8669 - recall: 0.8380 - val_accuracy: 0.7540 - val_auc: 0.9088 - val_loss: 0.5993 - val_precision: 0.7647 - val_recall: 0.7222 - learning_rate: 3.2768e-05
# Epoch 53/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8547 - auc: 0.9640 - loss: 0.3641 - precision: 0.8689 - recall: 0.8350 - val_accuracy: 0.7540 - val_auc: 0.9109 - val_loss: 0.5965 - val_precision: 0.7722 - val_recall: 0.7354 - learning_rate: 2.6214e-05
# Epoch 54/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8562 - auc: 0.9644 - loss: 0.3630 - precision: 0.8700 - recall: 0.8392 - val_accuracy: 0.7487 - val_auc: 0.9103 - val_loss: 0.5914 - val_precision: 0.7626 - val_recall: 0.7222 - learning_rate: 2.6214e-05
# Epoch 55/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8553 - auc: 0.9637 - loss: 0.3656 - precision: 0.8706 - recall: 0.8392 - val_accuracy: 0.7460 - val_auc: 0.9130 - val_loss: 0.5838 - val_precision: 0.7652 - val_recall: 0.7328 - learning_rate: 2.6214e-05
# Epoch 56/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8551 - auc: 0.9662 - loss: 0.3530 - precision: 0.8695 - recall: 0.8415 - val_accuracy: 0.7778 - val_auc: 0.9117 - val_loss: 0.5954 - val_precision: 0.7885 - val_recall: 0.7593 - learning_rate: 2.6214e-05
# Epoch 57/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8608 - auc: 0.9682 - loss: 0.3444 - precision: 0.8741 - recall: 0.8433 - val_accuracy: 0.7566 - val_auc: 0.9119 - val_loss: 0.5911 - val_precision: 0.7762 - val_recall: 0.7434 - learning_rate: 2.6214e-05
# Epoch 58/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8593 - auc: 0.9653 - loss: 0.3561 - precision: 0.8738 - recall: 0.8421 - val_accuracy: 0.7725 - val_auc: 0.9146 - val_loss: 0.5865 - val_precision: 0.7824 - val_recall: 0.7513 - learning_rate: 2.6214e-05
# Epoch 59/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8654 - auc: 0.9668 - loss: 0.3490 - precision: 0.8840 - recall: 0.8504 - val_accuracy: 0.7619 - val_auc: 0.9106 - val_loss: 0.5936 - val_precision: 0.7765 - val_recall: 0.7354 - learning_rate: 2.6214e-05
# Epoch 60/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - accuracy: 0.8616 - auc: 0.9672 - loss: 0.3471 - precision: 0.8755 - recall: 0.8444 - val_accuracy: 0.7593 - val_auc: 0.9135 - val_loss: 0.5891 - val_precision: 0.7853 - val_recall: 0.7354 - learning_rate: 2.6214e-05
# Epoch 61/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8666 - auc: 0.9686 - loss: 0.3402 - precision: 0.8801 - recall: 0.8493
# Epoch 61: ReduceLROnPlateau reducing learning rate to 2.09715188248083e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8666 - auc: 0.9686 - loss: 0.3404 - precision: 0.8800 - recall: 0.8492 - val_accuracy: 0.7804 - val_auc: 0.9141 - val_loss: 0.5871 - val_precision: 0.7863 - val_recall: 0.7593 - learning_rate: 2.6214e-05
# Epoch 62/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8682 - auc: 0.9677 - loss: 0.3461 - precision: 0.8795 - recall: 0.8471 - val_accuracy: 0.7619 - val_auc: 0.9142 - val_loss: 0.5871 - val_precision: 0.7778 - val_recall: 0.7407 - learning_rate: 2.0972e-05
# Epoch 63/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8592 - auc: 0.9706 - loss: 0.3325 - precision: 0.8772 - recall: 0.8460 - val_accuracy: 0.7778 - val_auc: 0.9153 - val_loss: 0.5841 - val_precision: 0.7912 - val_recall: 0.7619 - learning_rate: 2.0972e-05
# Epoch 64/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8670 - auc: 0.9677 - loss: 0.3465 - precision: 0.8793 - recall: 0.8508 - val_accuracy: 0.7751 - val_auc: 0.9153 - val_loss: 0.5867 - val_precision: 0.7855 - val_recall: 0.7460 - learning_rate: 2.0972e-05
# Epoch 65/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8675 - auc: 0.9689 - loss: 0.3393 - precision: 0.8806 - recall: 0.8510 - val_accuracy: 0.7619 - val_auc: 0.9167 - val_loss: 0.5770 - val_precision: 0.7883 - val_recall: 0.7487 - learning_rate: 2.0972e-05
# Epoch 66/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8611 - auc: 0.9677 - loss: 0.3432 - precision: 0.8757 - recall: 0.8480 - val_accuracy: 0.7725 - val_auc: 0.9172 - val_loss: 0.5776 - val_precision: 0.7885 - val_recall: 0.7593 - learning_rate: 2.0972e-05
# Epoch 67/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - accuracy: 0.8587 - auc: 0.9684 - loss: 0.3418 - precision: 0.8740 - recall: 0.8435 - val_accuracy: 0.7619 - val_auc: 0.9156 - val_loss: 0.5802 - val_precision: 0.7772 - val_recall: 0.7381 - learning_rate: 2.0972e-05
# Epoch 68/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8690 - auc: 0.9704 - loss: 0.3302 - precision: 0.8849 - recall: 0.8522 - val_accuracy: 0.7725 - val_auc: 0.9166 - val_loss: 0.5838 - val_precision: 0.7802 - val_recall: 0.7513 - learning_rate: 2.0972e-05
# Epoch 69/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8649 - auc: 0.9709 - loss: 0.3284 - precision: 0.8782 - recall: 0.8538
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1.6777214477770033e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8648 - auc: 0.9708 - loss: 0.3285 - precision: 0.8781 - recall: 0.8537 - val_accuracy: 0.7778 - val_auc: 0.9156 - val_loss: 0.5786 - val_precision: 0.7883 - val_recall: 0.7487 - learning_rate: 2.0972e-05
# Epoch 70/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8658 - auc: 0.9711 - loss: 0.3278 - precision: 0.8856 - recall: 0.8483 - val_accuracy: 0.7698 - val_auc: 0.9171 - val_loss: 0.5815 - val_precision: 0.7899 - val_recall: 0.7460 - learning_rate: 1.6777e-05
# Epoch 71/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8753 - auc: 0.9727 - loss: 0.3188 - precision: 0.8878 - recall: 0.8578 - val_accuracy: 0.7646 - val_auc: 0.9164 - val_loss: 0.5867 - val_precision: 0.7851 - val_recall: 0.7540 - learning_rate: 1.6777e-05
# Epoch 72/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8720 - auc: 0.9717 - loss: 0.3241 - precision: 0.8843 - recall: 0.8573
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1.3421771291177721e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8719 - auc: 0.9717 - loss: 0.3243 - precision: 0.8842 - recall: 0.8572 - val_accuracy: 0.7698 - val_auc: 0.9165 - val_loss: 0.5831 - val_precision: 0.7879 - val_recall: 0.7566 - learning_rate: 1.6777e-05
# Epoch 73/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8712 - auc: 0.9713 - loss: 0.3263 - precision: 0.8828 - recall: 0.8568 - val_accuracy: 0.7698 - val_auc: 0.9180 - val_loss: 0.5752 - val_precision: 0.7950 - val_recall: 0.7593 - learning_rate: 1.3422e-05
# Epoch 74/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8702 - auc: 0.9716 - loss: 0.3258 - precision: 0.8838 - recall: 0.8557 - val_accuracy: 0.7672 - val_auc: 0.9187 - val_loss: 0.5741 - val_precision: 0.7911 - val_recall: 0.7513 - learning_rate: 1.3422e-05
# Epoch 75/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8706 - auc: 0.9709 - loss: 0.3299 - precision: 0.8851 - recall: 0.8543 - val_accuracy: 0.7804 - val_auc: 0.9178 - val_loss: 0.5769 - val_precision: 0.7950 - val_recall: 0.7593 - learning_rate: 1.3422e-05
# Epoch 76/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8774 - auc: 0.9744 - loss: 0.3109 - precision: 0.8910 - recall: 0.8594 - val_accuracy: 0.7804 - val_auc: 0.9191 - val_loss: 0.5740 - val_precision: 0.7889 - val_recall: 0.7513 - learning_rate: 1.3422e-05
# Epoch 77/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8680 - auc: 0.9705 - loss: 0.3305 - precision: 0.8829 - recall: 0.8541 - val_accuracy: 0.7910 - val_auc: 0.9198 - val_loss: 0.5737 - val_precision: 0.8006 - val_recall: 0.7646 - learning_rate: 1.3422e-05
# Epoch 78/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - accuracy: 0.8732 - auc: 0.9716 - loss: 0.3240 - precision: 0.8858 - recall: 0.8564 - val_accuracy: 0.7831 - val_auc: 0.9187 - val_loss: 0.5743 - val_precision: 0.7994 - val_recall: 0.7593 - learning_rate: 1.3422e-05
# Epoch 79/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8751 - auc: 0.9745 - loss: 0.3105 - precision: 0.8897 - recall: 0.8622 - val_accuracy: 0.7672 - val_auc: 0.9191 - val_loss: 0.5736 - val_precision: 0.7849 - val_recall: 0.7434 - learning_rate: 1.3422e-05
# Epoch 80/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8777 - auc: 0.9731 - loss: 0.3156 - precision: 0.8881 - recall: 0.8648
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.0737417323980481e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8776 - auc: 0.9731 - loss: 0.3158 - precision: 0.8880 - recall: 0.8647 - val_accuracy: 0.7751 - val_auc: 0.9191 - val_loss: 0.5724 - val_precision: 0.7833 - val_recall: 0.7460 - learning_rate: 1.3422e-05
# Epoch 81/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8740 - auc: 0.9736 - loss: 0.3144 - precision: 0.8911 - recall: 0.8604 - val_accuracy: 0.7857 - val_auc: 0.9203 - val_loss: 0.5692 - val_precision: 0.7951 - val_recall: 0.7698 - learning_rate: 1.0737e-05
# Epoch 82/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8646 - auc: 0.9701 - loss: 0.3324 - precision: 0.8747 - recall: 0.8450 - val_accuracy: 0.7698 - val_auc: 0.9193 - val_loss: 0.5740 - val_precision: 0.7845 - val_recall: 0.7513 - learning_rate: 1.0737e-05
# Epoch 83/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8760 - auc: 0.9738 - loss: 0.3118 - precision: 0.8889 - recall: 0.8595 - val_accuracy: 0.7698 - val_auc: 0.9199 - val_loss: 0.5733 - val_precision: 0.7905 - val_recall: 0.7487 - learning_rate: 1.0737e-05
# Epoch 84/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8629 - auc: 0.9718 - loss: 0.3218 - precision: 0.8748 - recall: 0.8470
# Epoch 84: ReduceLROnPlateau reducing learning rate to 8.589933713665232e-06.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8628 - auc: 0.9718 - loss: 0.3220 - precision: 0.8748 - recall: 0.8469 - val_accuracy: 0.7698 - val_auc: 0.9190 - val_loss: 0.5731 - val_precision: 0.7824 - val_recall: 0.7513 - learning_rate: 1.0737e-05
# Epoch 85/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8786 - auc: 0.9751 - loss: 0.3038 - precision: 0.8926 - recall: 0.8599 - val_accuracy: 0.7831 - val_auc: 0.9200 - val_loss: 0.5707 - val_precision: 0.8006 - val_recall: 0.7646 - learning_rate: 8.5899e-06
# Epoch 86/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8827 - auc: 0.9752 - loss: 0.3052 - precision: 0.8957 - recall: 0.8713 - val_accuracy: 0.7804 - val_auc: 0.9188 - val_loss: 0.5759 - val_precision: 0.7973 - val_recall: 0.7698 - learning_rate: 8.5899e-06
# Epoch 87/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8815 - auc: 0.9753 - loss: 0.3039 - precision: 0.8899 - recall: 0.8626
# Epoch 87: ReduceLROnPlateau reducing learning rate to 6.871946970932186e-06.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8814 - auc: 0.9753 - loss: 0.3041 - precision: 0.8898 - recall: 0.8625 - val_accuracy: 0.7804 - val_auc: 0.9186 - val_loss: 0.5744 - val_precision: 0.7923 - val_recall: 0.7672 - learning_rate: 8.5899e-06
# Epoch 88/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - accuracy: 0.8863 - auc: 0.9767 - loss: 0.2958 - precision: 0.8986 - recall: 0.8727 - val_accuracy: 0.7910 - val_auc: 0.9206 - val_loss: 0.5709 - val_precision: 0.8028 - val_recall: 0.7646 - learning_rate: 6.8719e-06
# Epoch 89/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8824 - auc: 0.9747 - loss: 0.3078 - precision: 0.8926 - recall: 0.8664 - val_accuracy: 0.7963 - val_auc: 0.9203 - val_loss: 0.5712 - val_precision: 0.8006 - val_recall: 0.7646 - learning_rate: 6.8719e-06
# Epoch 90/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8663 - auc: 0.9718 - loss: 0.3236 - precision: 0.8778 - recall: 0.8504 - val_accuracy: 0.7857 - val_auc: 0.9209 - val_loss: 0.5706 - val_precision: 0.8033 - val_recall: 0.7672 - learning_rate: 6.8719e-06
# Epoch 91/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8869 - auc: 0.9774 - loss: 0.2937 - precision: 0.9001 - recall: 0.8694 - val_accuracy: 0.7804 - val_auc: 0.9195 - val_loss: 0.5739 - val_precision: 0.7978 - val_recall: 0.7619 - learning_rate: 6.8719e-06
# Epoch 92/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8702 - auc: 0.9728 - loss: 0.3173 - precision: 0.8799 - recall: 0.8577 - val_accuracy: 0.7910 - val_auc: 0.9194 - val_loss: 0.5729 - val_precision: 0.7972 - val_recall: 0.7593 - learning_rate: 6.8719e-06
# Epoch 93/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8854 - auc: 0.9777 - loss: 0.2914 - precision: 0.8964 - recall: 0.8708
# Epoch 93: ReduceLROnPlateau reducing learning rate to 5.497557503986173e-06.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8853 - auc: 0.9776 - loss: 0.2916 - precision: 0.8963 - recall: 0.8707 - val_accuracy: 0.7884 - val_auc: 0.9199 - val_loss: 0.5732 - val_precision: 0.8039 - val_recall: 0.7698 - learning_rate: 6.8719e-06
# Epoch 94/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8755 - auc: 0.9735 - loss: 0.3126 - precision: 0.8901 - recall: 0.8611 - val_accuracy: 0.7884 - val_auc: 0.9203 - val_loss: 0.5719 - val_precision: 0.8039 - val_recall: 0.7593 - learning_rate: 5.4976e-06
# Epoch 95/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8793 - auc: 0.9739 - loss: 0.3106 - precision: 0.8905 - recall: 0.8647 - val_accuracy: 0.7910 - val_auc: 0.9205 - val_loss: 0.5728 - val_precision: 0.8067 - val_recall: 0.7619 - learning_rate: 5.4976e-06
# Epoch 96/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8868 - auc: 0.9747 - loss: 0.3050 - precision: 0.8975 - recall: 0.8727
# Epoch 96: ReduceLROnPlateau reducing learning rate to 4.398046075948514e-06.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8867 - auc: 0.9747 - loss: 0.3052 - precision: 0.8974 - recall: 0.8726 - val_accuracy: 0.7857 - val_auc: 0.9204 - val_loss: 0.5699 - val_precision: 0.7940 - val_recall: 0.7646 - learning_rate: 5.4976e-06
# Epoch 97/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.8844 - auc: 0.9760 - loss: 0.3001 - precision: 0.8954 - recall: 0.8737 - val_accuracy: 0.7857 - val_auc: 0.9205 - val_loss: 0.5726 - val_precision: 0.7961 - val_recall: 0.7646 - learning_rate: 4.3980e-06
# Epoch 98/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - accuracy: 0.8780 - auc: 0.9749 - loss: 0.3055 - precision: 0.8913 - recall: 0.8677 - val_accuracy: 0.7857 - val_auc: 0.9208 - val_loss: 0.5719 - val_precision: 0.7983 - val_recall: 0.7646 - learning_rate: 4.3980e-06

# %% [markdown]
# # FINE-TUNING

# %%
for layer in model.layers[1:-8]:
    layer.trainable = True

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=5e-5), loss="categorical_crossentropy", metrics=metrics)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 3)                   │             771 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,112,515 (57.65 MB)
#  Trainable params: 15,110,979 (57.64 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
history = model.fit( trainDataset,
                         validation_data=validDataset,
                         epochs=250,
                         callbacks=[early_stopping, reduceLRCallback],
                         verbose=1)
# Out:
# Epoch 1/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 89s 269ms/step - accuracy: 0.5856 - auc: 0.8017 - loss: 1.0240 - precision: 0.6320 - recall: 0.5815 - val_accuracy: 0.4762 - val_auc: 0.6264 - val_loss: 3.0751 - val_precision: 0.4762 - val_recall: 0.4762 - learning_rate: 5.0000e-05
# Epoch 2/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 255ms/step - accuracy: 0.6361 - auc: 0.8163 - loss: 0.8807 - precision: 0.6589 - recall: 0.5928 - val_accuracy: 0.4868 - val_auc: 0.6430 - val_loss: 2.0261 - val_precision: 0.4906 - val_recall: 0.4841 - learning_rate: 5.0000e-05
# Epoch 3/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 255ms/step - accuracy: 0.6597 - auc: 0.8359 - loss: 0.8195 - precision: 0.6887 - recall: 0.6109 - val_accuracy: 0.4153 - val_auc: 0.6645 - val_loss: 2.3984 - val_precision: 0.4071 - val_recall: 0.3942 - learning_rate: 5.0000e-05
# Epoch 4/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 255ms/step - accuracy: 0.6766 - auc: 0.8480 - loss: 0.7831 - precision: 0.7037 - recall: 0.6308 - val_accuracy: 0.5688 - val_auc: 0.7959 - val_loss: 0.9255 - val_precision: 0.6133 - val_recall: 0.5370 - learning_rate: 5.0000e-05
# Epoch 5/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 255ms/step - accuracy: 0.6960 - auc: 0.8692 - loss: 0.7178 - precision: 0.7297 - recall: 0.6517 - val_accuracy: 0.5397 - val_auc: 0.7527 - val_loss: 1.3507 - val_precision: 0.5362 - val_recall: 0.5291 - learning_rate: 5.0000e-05
# Epoch 6/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 255ms/step - accuracy: 0.7330 - auc: 0.8968 - loss: 0.6241 - precision: 0.7624 - recall: 0.6966 - val_accuracy: 0.5899 - val_auc: 0.7862 - val_loss: 1.1645 - val_precision: 0.5956 - val_recall: 0.5767 - learning_rate: 5.0000e-05
# Epoch 7/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 255ms/step - accuracy: 0.7722 - auc: 0.9207 - loss: 0.5440 - precision: 0.7992 - recall: 0.7369 - val_accuracy: 0.6825 - val_auc: 0.8604 - val_loss: 0.8103 - val_precision: 0.7254 - val_recall: 0.6429 - learning_rate: 5.0000e-05
# Epoch 8/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 254ms/step - accuracy: 0.7797 - auc: 0.9343 - loss: 0.4948 - precision: 0.8085 - recall: 0.7552 - val_accuracy: 0.6852 - val_auc: 0.8751 - val_loss: 0.7443 - val_precision: 0.7106 - val_recall: 0.6561 - learning_rate: 5.0000e-05
# Epoch 9/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 254ms/step - accuracy: 0.8235 - auc: 0.9520 - loss: 0.4197 - precision: 0.8394 - recall: 0.8047 - val_accuracy: 0.6190 - val_auc: 0.7870 - val_loss: 1.4339 - val_precision: 0.6243 - val_recall: 0.6111 - learning_rate: 5.0000e-05
# Epoch 10/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 254ms/step - accuracy: 0.8358 - auc: 0.9574 - loss: 0.3973 - precision: 0.8529 - recall: 0.8165 - val_accuracy: 0.6534 - val_auc: 0.8381 - val_loss: 0.9748 - val_precision: 0.6685 - val_recall: 0.6349 - learning_rate: 5.0000e-05
# Epoch 11/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 254ms/step - accuracy: 0.8618 - auc: 0.9673 - loss: 0.3432 - precision: 0.8756 - recall: 0.8441 - val_accuracy: 0.7302 - val_auc: 0.8899 - val_loss: 0.7050 - val_precision: 0.7344 - val_recall: 0.7169 - learning_rate: 5.0000e-05
# Epoch 12/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 254ms/step - accuracy: 0.8660 - auc: 0.9711 - loss: 0.3216 - precision: 0.8773 - recall: 0.8519 - val_accuracy: 0.7090 - val_auc: 0.8839 - val_loss: 0.8392 - val_precision: 0.7198 - val_recall: 0.6931 - learning_rate: 5.0000e-05
# Epoch 13/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 254ms/step - accuracy: 0.8911 - auc: 0.9789 - loss: 0.2721 - precision: 0.9007 - recall: 0.8798 - val_accuracy: 0.7513 - val_auc: 0.9245 - val_loss: 0.5815 - val_precision: 0.7568 - val_recall: 0.7407 - learning_rate: 5.0000e-05
# Epoch 14/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 253ms/step - accuracy: 0.8916 - auc: 0.9808 - loss: 0.2604 - precision: 0.8993 - recall: 0.8857 - val_accuracy: 0.7434 - val_auc: 0.9056 - val_loss: 0.7663 - val_precision: 0.7589 - val_recall: 0.7328 - learning_rate: 5.0000e-05
# Epoch 15/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 253ms/step - accuracy: 0.9157 - auc: 0.9871 - loss: 0.2105 - precision: 0.9208 - recall: 0.9091 - val_accuracy: 0.7460 - val_auc: 0.9000 - val_loss: 0.8110 - val_precision: 0.7548 - val_recall: 0.7328 - learning_rate: 5.0000e-05
# Epoch 16/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9257 - auc: 0.9894 - loss: 0.1916 - precision: 0.9311 - recall: 0.9212
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 253ms/step - accuracy: 0.9257 - auc: 0.9894 - loss: 0.1918 - precision: 0.9310 - recall: 0.9211 - val_accuracy: 0.7011 - val_auc: 0.8738 - val_loss: 0.9311 - val_precision: 0.7068 - val_recall: 0.6825 - learning_rate: 5.0000e-05
# Epoch 17/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 254ms/step - accuracy: 0.9255 - auc: 0.9904 - loss: 0.1811 - precision: 0.9291 - recall: 0.9238 - val_accuracy: 0.7778 - val_auc: 0.9302 - val_loss: 0.6423 - val_precision: 0.7849 - val_recall: 0.7725 - learning_rate: 4.0000e-05
# Epoch 18/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 254ms/step - accuracy: 0.9388 - auc: 0.9935 - loss: 0.1475 - precision: 0.9404 - recall: 0.9361 - val_accuracy: 0.7672 - val_auc: 0.9318 - val_loss: 0.6422 - val_precision: 0.7733 - val_recall: 0.7672 - learning_rate: 4.0000e-05
# Epoch 19/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 253ms/step - accuracy: 0.9366 - auc: 0.9935 - loss: 0.1510 - precision: 0.9379 - recall: 0.9316 - val_accuracy: 0.7989 - val_auc: 0.9385 - val_loss: 0.5848 - val_precision: 0.8086 - val_recall: 0.7937 - learning_rate: 4.0000e-05
# Epoch 20/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 253ms/step - accuracy: 0.9527 - auc: 0.9960 - loss: 0.1193 - precision: 0.9551 - recall: 0.9502 - val_accuracy: 0.7804 - val_auc: 0.9331 - val_loss: 0.5584 - val_precision: 0.7859 - val_recall: 0.7672 - learning_rate: 4.0000e-05
# Epoch 21/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 253ms/step - accuracy: 0.9487 - auc: 0.9958 - loss: 0.1208 - precision: 0.9514 - recall: 0.9447 - val_accuracy: 0.7619 - val_auc: 0.9150 - val_loss: 0.6656 - val_precision: 0.7678 - val_recall: 0.7434 - learning_rate: 4.0000e-05
# Epoch 22/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9539 - auc: 0.9962 - loss: 0.1145 - precision: 0.9558 - recall: 0.9527
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.199999919161201e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 253ms/step - accuracy: 0.9539 - auc: 0.9962 - loss: 0.1146 - precision: 0.9557 - recall: 0.9526 - val_accuracy: 0.6481 - val_auc: 0.8336 - val_loss: 1.3496 - val_precision: 0.6550 - val_recall: 0.6429 - learning_rate: 4.0000e-05
# Epoch 23/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 253ms/step - accuracy: 0.9632 - auc: 0.9968 - loss: 0.1025 - precision: 0.9649 - recall: 0.9613 - val_accuracy: 0.7778 - val_auc: 0.9216 - val_loss: 0.7632 - val_precision: 0.7855 - val_recall: 0.7751 - learning_rate: 3.2000e-05
# Epoch 24/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 253ms/step - accuracy: 0.9651 - auc: 0.9978 - loss: 0.0861 - precision: 0.9671 - recall: 0.9642 - val_accuracy: 0.7831 - val_auc: 0.9255 - val_loss: 0.6611 - val_precision: 0.7951 - val_recall: 0.7804 - learning_rate: 3.2000e-05
# Epoch 25/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9598 - auc: 0.9972 - loss: 0.0965 - precision: 0.9615 - recall: 0.9580
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.5599999935366215e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 253ms/step - accuracy: 0.9598 - auc: 0.9972 - loss: 0.0965 - precision: 0.9615 - recall: 0.9580 - val_accuracy: 0.8095 - val_auc: 0.9239 - val_loss: 0.7472 - val_precision: 0.8194 - val_recall: 0.8042 - learning_rate: 3.2000e-05
# Epoch 26/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 253ms/step - accuracy: 0.9653 - auc: 0.9980 - loss: 0.0792 - precision: 0.9667 - recall: 0.9627 - val_accuracy: 0.7963 - val_auc: 0.9260 - val_loss: 0.6709 - val_precision: 0.8011 - val_recall: 0.7884 - learning_rate: 2.5600e-05
# Epoch 27/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 49s 253ms/step - accuracy: 0.9658 - auc: 0.9983 - loss: 0.0743 - precision: 0.9675 - recall: 0.9649 - val_accuracy: 0.7937 - val_auc: 0.9168 - val_loss: 0.8139 - val_precision: 0.7962 - val_recall: 0.7857 - learning_rate: 2.5600e-05

# %% [markdown]
# # PLOTS

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %% [markdown]
# # PR Curve

# %%
valid_labels = []
for xBatch, yBatch in validDataset:
    valid_labels.extend(np.argmax(yBatch, axis=1))
predictions = model.predict(validDataset)
predicted_classes = np.argmax(predictions, axis=1)
yTrue = np.eye(3)[valid_labels]
yPred = predictions
thresholds = {}
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step

# %%
for class_idx in range(3):
    precision, recall, thresholds_pr = precision_recall_curve(yTrue[:, class_idx], yPred[:, class_idx])

    f1_scores = 2 * (precision * recall) / (precision + recall)

    optimal_threshold_pr = thresholds_pr[np.argmax(f1_scores)]
    thresholds[class_idx] = optimal_threshold_pr

    plt.plot(recall, precision, label=f'Class {class_idx} (area = {auc(recall, precision):.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve for each class')
plt.legend(loc="best")
plt.show()

# %%
print("Optimal thresholds for each class (based on maximum F1 score):")
for class_idx, threshold in thresholds.items():
    print(f"Class {class_idx}: {threshold}")
# Out:
# Optimal thresholds for each class (based on maximum F1 score):
# Class 0: 0.5739341974258423
# Class 1: 0.1319325715303421
# Class 2: 0.266340047121048

# %% [markdown]
# # TESTING

# %%
def customPredict(yPred, thresholds):
    predictions = np.zeros_like(yPred)
    for i in thresholds.keys():
        threshold = thresholds[i]
        predictions[:, i] = (yPred[:, i] >= threshold).astype(int)
    predictions = np.argmax(predictions * yPred, axis=1)
    return predictions

# %%
test_labels = []
for xBatch, yBatch in testDataset:
    test_labels.extend(np.argmax(yBatch, axis=1))
predictions = customPredict(model.predict(testDataset), thresholds)
# predictions = np.argmax(model.predict(testDataset), axis=1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step

# %%
report = classification_report(test_labels, predictions, target_names=categories)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.89      0.86      0.87       126
#   Osteopenia       0.83      0.87      0.85       126
# Osteoporosis       0.87      0.87      0.87       126
#
#     accuracy                           0.87       378
#    macro avg       0.87      0.87      0.87       378
# weighted avg       0.87      0.87      0.87       378

# %%
conf_matrix = confusion_matrix(test_labels, predictions)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=categories,
            yticklabels=categories)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
# Out:
# Text(95.72222222222221, 0.5, 'True Label')

# %%
runtime.unassign()
