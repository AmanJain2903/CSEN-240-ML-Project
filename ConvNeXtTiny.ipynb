# %% [markdown]
# # IMPORT DEPENDENCIES

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from sklearn.preprocessing import LabelEncoder
import time
import shutil
import pathlib
import itertools
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")
from tensorflow.keras.metrics import Precision, Recall, AUC
# from google.colab import runtime
from sklearn.metrics import f1_score, roc_curve, auc, precision_recall_curve
import zipfile

# %% [markdown]
# # LOADING DATA

# %%
batch_size = 32
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
categories = ["Normal","Osteopenia", "Osteoporosis"]

# %%
TfDatasetsPath = "/kaggle/input/tfdataset/TfDatasets"
# TfDatasetsPath = 'TfDatasets'

# %%
trainDataset = tf.data.Dataset.load(TfDatasetsPath + "/trainDataset")
validDataset = tf.data.Dataset.load(TfDatasetsPath + "/validDataset")
testDataset = tf.data.Dataset.load(TfDatasetsPath + "/testDataset")

# %%
def augment(image, label):
    image = tf.image.random_brightness(image, max_delta=0.1)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    image = tf.image.random_saturation(image, lower=0.8, upper=1.2)
    image = tf.image.random_hue(image, max_delta=0.1)
    image = tf.image.random_flip_up_down(image)
    image - tf.image.rot90(image, k=tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32))
    return image, label

# %%
augmentedDataset = trainDataset.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
trainDataset = trainDataset.concatenate(augmentedDataset)

# %%
len(list(trainDataset)), len(list(validDataset)), len(list(testDataset))
# Out:
# (6048, 378, 378)

# %%
trainDataset = trainDataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)
validDataset = validDataset.batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)
testDataset = testDataset.batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
trainDataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
metrics = [Precision(), Recall(), AUC(), 'accuracy']

# %% [markdown]
# # ConvNeXtTiny Model

# %%
def createModel(input_shape, num_classes=3, learning_rate=1e-4):
    inputs = tf.keras.layers.Input(shape=input_shape)
    base_model = tf.keras.applications.ConvNeXtTiny(weights="imagenet", input_tensor=inputs, include_top=False)
    base_model.trainable = False
    x = base_model.output
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(512, activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.25)(x)
    x = tf.keras.layers.Dense(256, activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.25)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss="categorical_crossentropy", metrics=metrics)
    return model

# %% [markdown]
# # TRAINING

# %%
input_shape = (224, 224, 3)
model = createModel(input_shape, num_classes=3, learning_rate=1e-4)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_tiny_notop.h5
# 111650432/111650432 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.summary()
# Out:
# Model: "functional_4"
#  Trainable params: 527,363 (2.01 MB)
#  Non-trainable params: 27,821,664 (106.13 MB)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_auc', mode='max', patience=8, restore_best_weights=True)

# %%
# Defining The ReduceLRonPlateau Callback
reduceLRCallback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_auc',
    factor=0.8, # How much to improve the learning rate -> LR = LR*factor
    patience=3,
    verbose=1,
    mode='max',
    min_delta=0.0001, # Change in metric below this delta is considered as no change
    cooldown=0, # Number of epochs to wait before resuming normal operation after lr has been improved
    min_lr=0 # Learning Rate won't go below this
)

# %%
history = model.fit(trainDataset,
                        validation_data=validDataset,
                        epochs=250,
                        callbacks=[early_stopping, reduceLRCallback],
                        verbose=1)
# Out:
# Epoch 1/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 40s 124ms/step - accuracy: 0.4490 - auc: 0.6425 - loss: 1.2966 - precision: 0.4690 - recall: 0.3860 - val_accuracy: 0.3333 - val_auc: 0.5851 - val_loss: 1.1120 - val_precision: 0.4710 - val_recall: 0.1931 - learning_rate: 1.0000e-04
# Epoch 2/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.5503 - auc: 0.7432 - loss: 1.0433 - precision: 0.5803 - recall: 0.4920 - val_accuracy: 0.4392 - val_auc: 0.6493 - val_loss: 1.0531 - val_precision: 0.4857 - val_recall: 0.3598 - learning_rate: 1.0000e-04
# Epoch 3/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.5635 - auc: 0.7631 - loss: 0.9786 - precision: 0.6005 - recall: 0.5016 - val_accuracy: 0.4788 - val_auc: 0.6889 - val_loss: 1.0159 - val_precision: 0.5537 - val_recall: 0.3545 - learning_rate: 1.0000e-04
# Epoch 4/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.5926 - auc: 0.7817 - loss: 0.9264 - precision: 0.6232 - recall: 0.5178 - val_accuracy: 0.5132 - val_auc: 0.7024 - val_loss: 1.1974 - val_precision: 0.5276 - val_recall: 0.5053 - learning_rate: 1.0000e-04
# Epoch 5/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - accuracy: 0.5999 - auc: 0.7860 - loss: 0.9147 - precision: 0.6300 - recall: 0.5337 - val_accuracy: 0.4259 - val_auc: 0.6735 - val_loss: 1.4101 - val_precision: 0.4294 - val_recall: 0.4021 - learning_rate: 1.0000e-04
# Epoch 6/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.5970 - auc: 0.7924 - loss: 0.8999 - precision: 0.6310 - recall: 0.5382 - val_accuracy: 0.6005 - val_auc: 0.7793 - val_loss: 0.9050 - val_precision: 0.6740 - val_recall: 0.4868 - learning_rate: 1.0000e-04
# Epoch 7/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.6134 - auc: 0.8041 - loss: 0.8667 - precision: 0.6466 - recall: 0.5461 - val_accuracy: 0.5317 - val_auc: 0.7520 - val_loss: 1.0695 - val_precision: 0.5372 - val_recall: 0.5159 - learning_rate: 1.0000e-04
# Epoch 8/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.6149 - auc: 0.8103 - loss: 0.8497 - precision: 0.6576 - recall: 0.5552 - val_accuracy: 0.5820 - val_auc: 0.7696 - val_loss: 0.9778 - val_precision: 0.5950 - val_recall: 0.5635 - learning_rate: 1.0000e-04
# Epoch 9/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6289 - auc: 0.8180 - loss: 0.8240 - precision: 0.6633 - recall: 0.5650
# Epoch 9: ReduceLROnPlateau reducing learning rate to 7.999999797903001e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.6288 - auc: 0.8179 - loss: 0.8242 - precision: 0.6633 - recall: 0.5649 - val_accuracy: 0.5847 - val_auc: 0.7689 - val_loss: 0.9390 - val_precision: 0.5920 - val_recall: 0.5450 - learning_rate: 1.0000e-04
# Epoch 10/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.6244 - auc: 0.8195 - loss: 0.8224 - precision: 0.6641 - recall: 0.5661 - val_accuracy: 0.5503 - val_auc: 0.7582 - val_loss: 0.9399 - val_precision: 0.6127 - val_recall: 0.4603 - learning_rate: 8.0000e-05
# Epoch 11/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.6362 - auc: 0.8235 - loss: 0.8052 - precision: 0.6706 - recall: 0.5650 - val_accuracy: 0.5450 - val_auc: 0.7565 - val_loss: 1.0636 - val_precision: 0.5590 - val_recall: 0.5265 - learning_rate: 8.0000e-05
# Epoch 12/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6454 - auc: 0.8290 - loss: 0.7923 - precision: 0.6758 - recall: 0.5819
# Epoch 12: ReduceLROnPlateau reducing learning rate to 6.399999838322402e-05.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - accuracy: 0.6453 - auc: 0.8290 - loss: 0.7926 - precision: 0.6757 - recall: 0.5818 - val_accuracy: 0.5741 - val_auc: 0.7726 - val_loss: 0.9717 - val_precision: 0.6105 - val_recall: 0.5556 - learning_rate: 8.0000e-05
# Epoch 13/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.6397 - auc: 0.8361 - loss: 0.7736 - precision: 0.6775 - recall: 0.5867 - val_accuracy: 0.5529 - val_auc: 0.7764 - val_loss: 0.9147 - val_precision: 0.5879 - val_recall: 0.5132 - learning_rate: 6.4000e-05
# Epoch 14/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - accuracy: 0.6573 - auc: 0.8395 - loss: 0.7705 - precision: 0.6937 - recall: 0.5896 - val_accuracy: 0.5635 - val_auc: 0.7506 - val_loss: 1.1048 - val_precision: 0.5859 - val_recall: 0.5503 - learning_rate: 6.4000e-05

# %% [markdown]
# # FINE-TUNING

# %%
for layer in model.layers[1:-8]:
    layer.trainable = True

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-6), loss="categorical_crossentropy", metrics=metrics)

# %%
model.summary()
# Out:
# Model: "functional_4"
#  Total params: 28,349,027 (108.14 MB)
#  Trainable params: 28,347,491 (108.14 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
history = model.fit( trainDataset,
                         validation_data=validDataset,
                         epochs=250,
                         callbacks=[early_stopping, reduceLRCallback],
                         verbose=1)
# Out:
# Epoch 1/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 105s 301ms/step - accuracy: 0.6209 - auc: 0.7942 - loss: 0.8619 - precision: 0.6397 - recall: 0.5543 - val_accuracy: 0.6508 - val_auc: 0.8200 - val_loss: 0.8264 - val_precision: 0.6943 - val_recall: 0.5767 - learning_rate: 2.0000e-06
# Epoch 2/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.6255 - auc: 0.8198 - loss: 0.8214 - precision: 0.6597 - recall: 0.5623 - val_accuracy: 0.6429 - val_auc: 0.8169 - val_loss: 0.8093 - val_precision: 0.6755 - val_recall: 0.5397 - learning_rate: 2.0000e-06
# Epoch 3/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 273ms/step - accuracy: 0.6529 - auc: 0.8313 - loss: 0.7996 - precision: 0.6904 - recall: 0.5968 - val_accuracy: 0.6508 - val_auc: 0.8229 - val_loss: 0.8013 - val_precision: 0.6925 - val_recall: 0.5899 - learning_rate: 2.0000e-06
# Epoch 4/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.6361 - auc: 0.8270 - loss: 0.8115 - precision: 0.6697 - recall: 0.5892 - val_accuracy: 0.6270 - val_auc: 0.8148 - val_loss: 0.8073 - val_precision: 0.6566 - val_recall: 0.5159 - learning_rate: 2.0000e-06
# Epoch 5/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 272ms/step - accuracy: 0.6386 - auc: 0.8290 - loss: 0.8014 - precision: 0.6714 - recall: 0.5815 - val_accuracy: 0.6296 - val_auc: 0.8124 - val_loss: 0.8217 - val_precision: 0.6757 - val_recall: 0.5291 - learning_rate: 2.0000e-06
# Epoch 6/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 274ms/step - accuracy: 0.6370 - auc: 0.8266 - loss: 0.8122 - precision: 0.6694 - recall: 0.5850 - val_accuracy: 0.6429 - val_auc: 0.8303 - val_loss: 0.7881 - val_precision: 0.6879 - val_recall: 0.5714 - learning_rate: 2.0000e-06
# Epoch 7/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 273ms/step - accuracy: 0.6510 - auc: 0.8341 - loss: 0.7944 - precision: 0.6779 - recall: 0.5957 - val_accuracy: 0.6852 - val_auc: 0.8365 - val_loss: 0.7735 - val_precision: 0.7100 - val_recall: 0.6217 - learning_rate: 2.0000e-06
# Epoch 8/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 273ms/step - accuracy: 0.6490 - auc: 0.8384 - loss: 0.7803 - precision: 0.6763 - recall: 0.5986 - val_accuracy: 0.6270 - val_auc: 0.8222 - val_loss: 0.8179 - val_precision: 0.6555 - val_recall: 0.5688 - learning_rate: 2.0000e-06
# Epoch 9/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.6606 - auc: 0.8472 - loss: 0.7556 - precision: 0.6935 - recall: 0.6146 - val_accuracy: 0.6534 - val_auc: 0.8341 - val_loss: 0.7796 - val_precision: 0.6883 - val_recall: 0.5899 - learning_rate: 2.0000e-06
# Epoch 10/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 273ms/step - accuracy: 0.6717 - auc: 0.8530 - loss: 0.7421 - precision: 0.7068 - recall: 0.6222 - val_accuracy: 0.6508 - val_auc: 0.8373 - val_loss: 0.7773 - val_precision: 0.6856 - val_recall: 0.6058 - learning_rate: 2.0000e-06
# Epoch 11/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.6763 - auc: 0.8507 - loss: 0.7550 - precision: 0.7088 - recall: 0.6312 - val_accuracy: 0.6481 - val_auc: 0.8377 - val_loss: 0.7770 - val_precision: 0.6864 - val_recall: 0.6138 - learning_rate: 2.0000e-06
# Epoch 12/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 273ms/step - accuracy: 0.6840 - auc: 0.8583 - loss: 0.7303 - precision: 0.7123 - recall: 0.6370 - val_accuracy: 0.6614 - val_auc: 0.8385 - val_loss: 0.7655 - val_precision: 0.6982 - val_recall: 0.6058 - learning_rate: 2.0000e-06
# Epoch 13/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.6955 - auc: 0.8681 - loss: 0.7011 - precision: 0.7234 - recall: 0.6499 - val_accuracy: 0.6587 - val_auc: 0.8362 - val_loss: 0.7718 - val_precision: 0.6994 - val_recall: 0.5847 - learning_rate: 2.0000e-06
# Epoch 14/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 273ms/step - accuracy: 0.7054 - auc: 0.8707 - loss: 0.6934 - precision: 0.7291 - recall: 0.6612 - val_accuracy: 0.6561 - val_auc: 0.8464 - val_loss: 0.7458 - val_precision: 0.7015 - val_recall: 0.6032 - learning_rate: 2.0000e-06
# Epoch 15/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.6925 - auc: 0.8696 - loss: 0.6937 - precision: 0.7188 - recall: 0.6399 - val_accuracy: 0.6905 - val_auc: 0.8503 - val_loss: 0.7489 - val_precision: 0.7134 - val_recall: 0.6323 - learning_rate: 2.0000e-06
# Epoch 16/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 272ms/step - accuracy: 0.6951 - auc: 0.8706 - loss: 0.6920 - precision: 0.7231 - recall: 0.6483 - val_accuracy: 0.6640 - val_auc: 0.8470 - val_loss: 0.7514 - val_precision: 0.6886 - val_recall: 0.6085 - learning_rate: 2.0000e-06
# Epoch 17/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 272ms/step - accuracy: 0.7048 - auc: 0.8787 - loss: 0.6689 - precision: 0.7346 - recall: 0.6627 - val_accuracy: 0.6429 - val_auc: 0.8470 - val_loss: 0.7520 - val_precision: 0.6637 - val_recall: 0.6005 - learning_rate: 2.0000e-06
# Epoch 18/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.7047 - auc: 0.8741 - loss: 0.6891 - precision: 0.7321 - recall: 0.6627
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.5999999959603884e-06.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7046 - auc: 0.8740 - loss: 0.6892 - precision: 0.7321 - recall: 0.6627 - val_accuracy: 0.6376 - val_auc: 0.8404 - val_loss: 0.7542 - val_precision: 0.6794 - val_recall: 0.5661 - learning_rate: 2.0000e-06
# Epoch 19/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 274ms/step - accuracy: 0.7119 - auc: 0.8801 - loss: 0.6669 - precision: 0.7397 - recall: 0.6697 - val_accuracy: 0.6772 - val_auc: 0.8569 - val_loss: 0.7272 - val_precision: 0.7246 - val_recall: 0.6402 - learning_rate: 1.6000e-06
# Epoch 20/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7149 - auc: 0.8879 - loss: 0.6434 - precision: 0.7491 - recall: 0.6777 - val_accuracy: 0.6614 - val_auc: 0.8453 - val_loss: 0.7541 - val_precision: 0.6905 - val_recall: 0.6138 - learning_rate: 1.6000e-06
# Epoch 21/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 274ms/step - accuracy: 0.7278 - auc: 0.8886 - loss: 0.6451 - precision: 0.7560 - recall: 0.6839 - val_accuracy: 0.6931 - val_auc: 0.8591 - val_loss: 0.7246 - val_precision: 0.7109 - val_recall: 0.6376 - learning_rate: 1.6000e-06
# Epoch 22/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7180 - auc: 0.8853 - loss: 0.6534 - precision: 0.7475 - recall: 0.6742 - val_accuracy: 0.6693 - val_auc: 0.8551 - val_loss: 0.7228 - val_precision: 0.7059 - val_recall: 0.6349 - learning_rate: 1.6000e-06
# Epoch 23/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7221 - auc: 0.8875 - loss: 0.6453 - precision: 0.7475 - recall: 0.6838 - val_accuracy: 0.6693 - val_auc: 0.8535 - val_loss: 0.7414 - val_precision: 0.6941 - val_recall: 0.6243 - learning_rate: 1.6000e-06
# Epoch 24/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 274ms/step - accuracy: 0.7188 - auc: 0.8879 - loss: 0.6440 - precision: 0.7441 - recall: 0.6771 - val_accuracy: 0.6825 - val_auc: 0.8600 - val_loss: 0.7246 - val_precision: 0.7122 - val_recall: 0.6481 - learning_rate: 1.6000e-06
# Epoch 25/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7382 - auc: 0.8977 - loss: 0.6150 - precision: 0.7657 - recall: 0.6912 - val_accuracy: 0.6931 - val_auc: 0.8622 - val_loss: 0.7182 - val_precision: 0.7160 - val_recall: 0.6402 - learning_rate: 1.6000e-06
# Epoch 26/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7269 - auc: 0.8939 - loss: 0.6226 - precision: 0.7550 - recall: 0.6869 - val_accuracy: 0.6720 - val_auc: 0.8519 - val_loss: 0.7401 - val_precision: 0.7009 - val_recall: 0.6138 - learning_rate: 1.6000e-06
# Epoch 27/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 274ms/step - accuracy: 0.7463 - auc: 0.9019 - loss: 0.5997 - precision: 0.7730 - recall: 0.7053 - val_accuracy: 0.6799 - val_auc: 0.8657 - val_loss: 0.7115 - val_precision: 0.6965 - val_recall: 0.6376 - learning_rate: 1.6000e-06
# Epoch 28/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 274ms/step - accuracy: 0.7482 - auc: 0.9023 - loss: 0.6016 - precision: 0.7770 - recall: 0.7106 - val_accuracy: 0.6799 - val_auc: 0.8672 - val_loss: 0.6980 - val_precision: 0.7273 - val_recall: 0.6349 - learning_rate: 1.6000e-06
# Epoch 29/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7446 - auc: 0.9043 - loss: 0.5941 - precision: 0.7666 - recall: 0.7083 - val_accuracy: 0.6905 - val_auc: 0.8629 - val_loss: 0.7185 - val_precision: 0.7066 - val_recall: 0.6561 - learning_rate: 1.6000e-06
# Epoch 30/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7399 - auc: 0.9040 - loss: 0.5916 - precision: 0.7655 - recall: 0.7014 - val_accuracy: 0.6905 - val_auc: 0.8669 - val_loss: 0.7059 - val_precision: 0.7164 - val_recall: 0.6481 - learning_rate: 1.6000e-06
# Epoch 31/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 273ms/step - accuracy: 0.7559 - auc: 0.9106 - loss: 0.5714 - precision: 0.7819 - recall: 0.7220 - val_accuracy: 0.7037 - val_auc: 0.8674 - val_loss: 0.6982 - val_precision: 0.7381 - val_recall: 0.6561 - learning_rate: 1.6000e-06
# Epoch 32/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 272ms/step - accuracy: 0.7482 - auc: 0.9087 - loss: 0.5751 - precision: 0.7716 - recall: 0.7112 - val_accuracy: 0.6984 - val_auc: 0.8654 - val_loss: 0.7089 - val_precision: 0.7193 - val_recall: 0.6508 - learning_rate: 1.6000e-06
# Epoch 33/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 274ms/step - accuracy: 0.7545 - auc: 0.9080 - loss: 0.5815 - precision: 0.7795 - recall: 0.7183 - val_accuracy: 0.6984 - val_auc: 0.8732 - val_loss: 0.6853 - val_precision: 0.7168 - val_recall: 0.6561 - learning_rate: 1.6000e-06
# Epoch 34/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7538 - auc: 0.9111 - loss: 0.5698 - precision: 0.7792 - recall: 0.7203 - val_accuracy: 0.6693 - val_auc: 0.8607 - val_loss: 0.7218 - val_precision: 0.6946 - val_recall: 0.6138 - learning_rate: 1.6000e-06
# Epoch 35/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 273ms/step - accuracy: 0.7593 - auc: 0.9148 - loss: 0.5583 - precision: 0.7874 - recall: 0.7218 - val_accuracy: 0.6984 - val_auc: 0.8702 - val_loss: 0.6987 - val_precision: 0.7135 - val_recall: 0.6587 - learning_rate: 1.6000e-06
# Epoch 36/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.7561 - auc: 0.9152 - loss: 0.5543 - precision: 0.7791 - recall: 0.7271
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.2800000149582048e-06.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7560 - auc: 0.9151 - loss: 0.5545 - precision: 0.7791 - recall: 0.7270 - val_accuracy: 0.6746 - val_auc: 0.8655 - val_loss: 0.7115 - val_precision: 0.7047 - val_recall: 0.6376 - learning_rate: 1.6000e-06
# Epoch 37/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7582 - auc: 0.9139 - loss: 0.5612 - precision: 0.7827 - recall: 0.7274 - val_accuracy: 0.6852 - val_auc: 0.8724 - val_loss: 0.6946 - val_precision: 0.6971 - val_recall: 0.6455 - learning_rate: 1.2800e-06
# Epoch 38/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7742 - auc: 0.9218 - loss: 0.5317 - precision: 0.7944 - recall: 0.7378 - val_accuracy: 0.7037 - val_auc: 0.8742 - val_loss: 0.6859 - val_precision: 0.7085 - val_recall: 0.6429 - learning_rate: 1.2800e-06
# Epoch 39/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7756 - auc: 0.9240 - loss: 0.5270 - precision: 0.7981 - recall: 0.7412 - val_accuracy: 0.6958 - val_auc: 0.8736 - val_loss: 0.6952 - val_precision: 0.7213 - val_recall: 0.6640 - learning_rate: 1.2800e-06
# Epoch 40/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7825 - auc: 0.9260 - loss: 0.5177 - precision: 0.8060 - recall: 0.7519 - val_accuracy: 0.6958 - val_auc: 0.8755 - val_loss: 0.6802 - val_precision: 0.7235 - val_recall: 0.6508 - learning_rate: 1.2800e-06
# Epoch 41/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 82s 273ms/step - accuracy: 0.7702 - auc: 0.9236 - loss: 0.5275 - precision: 0.7972 - recall: 0.7429 - val_accuracy: 0.7116 - val_auc: 0.8797 - val_loss: 0.6766 - val_precision: 0.7265 - val_recall: 0.6746 - learning_rate: 1.2800e-06
# Epoch 42/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7753 - auc: 0.9236 - loss: 0.5274 - precision: 0.7993 - recall: 0.7416 - val_accuracy: 0.6825 - val_auc: 0.8697 - val_loss: 0.7053 - val_precision: 0.7052 - val_recall: 0.6455 - learning_rate: 1.2800e-06
# Epoch 43/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7839 - auc: 0.9264 - loss: 0.5175 - precision: 0.8082 - recall: 0.7516 - val_accuracy: 0.7090 - val_auc: 0.8755 - val_loss: 0.6926 - val_precision: 0.7147 - val_recall: 0.6561 - learning_rate: 1.2800e-06
# Epoch 44/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7839 - auc: 0.9282 - loss: 0.5123 - precision: 0.8074 - recall: 0.7551 - val_accuracy: 0.7275 - val_auc: 0.8812 - val_loss: 0.6720 - val_precision: 0.7421 - val_recall: 0.6852 - learning_rate: 1.2800e-06
# Epoch 45/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7723 - auc: 0.9235 - loss: 0.5263 - precision: 0.7937 - recall: 0.7466 - val_accuracy: 0.7169 - val_auc: 0.8785 - val_loss: 0.6807 - val_precision: 0.7244 - val_recall: 0.6746 - learning_rate: 1.2800e-06
# Epoch 46/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 272ms/step - accuracy: 0.7876 - auc: 0.9325 - loss: 0.4955 - precision: 0.8119 - recall: 0.7593 - val_accuracy: 0.7037 - val_auc: 0.8780 - val_loss: 0.6834 - val_precision: 0.7203 - val_recall: 0.6746 - learning_rate: 1.2800e-06
# Epoch 47/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.7842 - auc: 0.9311 - loss: 0.4998 - precision: 0.8068 - recall: 0.7591
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.0239999937766699e-06.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7841 - auc: 0.9310 - loss: 0.5000 - precision: 0.8067 - recall: 0.7590 - val_accuracy: 0.6878 - val_auc: 0.8795 - val_loss: 0.6829 - val_precision: 0.7188 - val_recall: 0.6561 - learning_rate: 1.2800e-06
# Epoch 48/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7853 - auc: 0.9316 - loss: 0.4973 - precision: 0.8057 - recall: 0.7625 - val_accuracy: 0.7169 - val_auc: 0.8809 - val_loss: 0.6764 - val_precision: 0.7349 - val_recall: 0.6746 - learning_rate: 1.0240e-06
# Epoch 49/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7994 - auc: 0.9371 - loss: 0.4769 - precision: 0.8240 - recall: 0.7682 - val_accuracy: 0.7222 - val_auc: 0.8806 - val_loss: 0.6800 - val_precision: 0.7427 - val_recall: 0.6720 - learning_rate: 1.0240e-06
# Epoch 50/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7974 - auc: 0.9362 - loss: 0.4820 - precision: 0.8207 - recall: 0.7736 - val_accuracy: 0.7354 - val_auc: 0.8835 - val_loss: 0.6698 - val_precision: 0.7406 - val_recall: 0.6799 - learning_rate: 1.0240e-06
# Epoch 51/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7996 - auc: 0.9381 - loss: 0.4749 - precision: 0.8202 - recall: 0.7719 - val_accuracy: 0.7222 - val_auc: 0.8857 - val_loss: 0.6705 - val_precision: 0.7408 - val_recall: 0.6958 - learning_rate: 1.0240e-06
# Epoch 52/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.7906 - auc: 0.9351 - loss: 0.4851 - precision: 0.8105 - recall: 0.7608 - val_accuracy: 0.7169 - val_auc: 0.8828 - val_loss: 0.6722 - val_precision: 0.7364 - val_recall: 0.6799 - learning_rate: 1.0240e-06
# Epoch 53/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.8023 - auc: 0.9385 - loss: 0.4723 - precision: 0.8213 - recall: 0.7799 - val_accuracy: 0.7143 - val_auc: 0.8841 - val_loss: 0.6682 - val_precision: 0.7364 - val_recall: 0.6799 - learning_rate: 1.0240e-06
# Epoch 54/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.8020 - auc: 0.9367 - loss: 0.4821 - precision: 0.8204 - recall: 0.7746
# Epoch 54: ReduceLROnPlateau reducing learning rate to 8.191999768314418e-07.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 272ms/step - accuracy: 0.8019 - auc: 0.9366 - loss: 0.4823 - precision: 0.8203 - recall: 0.7745 - val_accuracy: 0.7116 - val_auc: 0.8847 - val_loss: 0.6701 - val_precision: 0.7330 - val_recall: 0.6825 - learning_rate: 1.0240e-06
# Epoch 55/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 274ms/step - accuracy: 0.7961 - auc: 0.9375 - loss: 0.4756 - precision: 0.8229 - recall: 0.7677 - val_accuracy: 0.7169 - val_auc: 0.8872 - val_loss: 0.6610 - val_precision: 0.7364 - val_recall: 0.6799 - learning_rate: 8.1920e-07
# Epoch 56/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.8033 - auc: 0.9397 - loss: 0.4654 - precision: 0.8209 - recall: 0.7823 - val_accuracy: 0.7090 - val_auc: 0.8850 - val_loss: 0.6665 - val_precision: 0.7379 - val_recall: 0.6852 - learning_rate: 8.1920e-07
# Epoch 57/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 53s 274ms/step - accuracy: 0.7979 - auc: 0.9387 - loss: 0.4694 - precision: 0.8175 - recall: 0.7694 - val_accuracy: 0.7249 - val_auc: 0.8888 - val_loss: 0.6576 - val_precision: 0.7386 - val_recall: 0.6878 - learning_rate: 8.1920e-07
# Epoch 58/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.8072 - auc: 0.9451 - loss: 0.4458 - precision: 0.8285 - recall: 0.7885 - val_accuracy: 0.7169 - val_auc: 0.8860 - val_loss: 0.6644 - val_precision: 0.7275 - val_recall: 0.6852 - learning_rate: 8.1920e-07
# Epoch 59/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 273ms/step - accuracy: 0.8071 - auc: 0.9431 - loss: 0.4548 - precision: 0.8274 - recall: 0.7781 - val_accuracy: 0.7037 - val_auc: 0.8829 - val_loss: 0.6732 - val_precision: 0.7326 - val_recall: 0.6667 - learning_rate: 8.1920e-07
# Epoch 60/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.8137 - auc: 0.9466 - loss: 0.4401 - precision: 0.8344 - recall: 0.7876
# Epoch 60: ReduceLROnPlateau reducing learning rate to 6.553599632752594e-07.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 272ms/step - accuracy: 0.8136 - auc: 0.9466 - loss: 0.4404 - precision: 0.8342 - recall: 0.7875 - val_accuracy: 0.7249 - val_auc: 0.8834 - val_loss: 0.6798 - val_precision: 0.7318 - val_recall: 0.6931 - learning_rate: 8.1920e-07
# Epoch 61/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 272ms/step - accuracy: 0.8074 - auc: 0.9440 - loss: 0.4487 - precision: 0.8315 - recall: 0.7846 - val_accuracy: 0.7116 - val_auc: 0.8869 - val_loss: 0.6662 - val_precision: 0.7322 - val_recall: 0.6799 - learning_rate: 6.5536e-07
# Epoch 62/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 272ms/step - accuracy: 0.8094 - auc: 0.9437 - loss: 0.4524 - precision: 0.8305 - recall: 0.7837 - val_accuracy: 0.7037 - val_auc: 0.8866 - val_loss: 0.6686 - val_precision: 0.7227 - val_recall: 0.6825 - learning_rate: 6.5536e-07
# Epoch 63/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.8065 - auc: 0.9438 - loss: 0.4504 - precision: 0.8289 - recall: 0.7871
# Epoch 63: ReduceLROnPlateau reducing learning rate to 5.242879524303135e-07.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 272ms/step - accuracy: 0.8064 - auc: 0.9438 - loss: 0.4506 - precision: 0.8289 - recall: 0.7870 - val_accuracy: 0.7116 - val_auc: 0.8872 - val_loss: 0.6686 - val_precision: 0.7311 - val_recall: 0.6905 - learning_rate: 6.5536e-07
# Epoch 64/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 272ms/step - accuracy: 0.8156 - auc: 0.9475 - loss: 0.4368 - precision: 0.8362 - recall: 0.7946 - val_accuracy: 0.7249 - val_auc: 0.8859 - val_loss: 0.6754 - val_precision: 0.7312 - val_recall: 0.6693 - learning_rate: 5.2429e-07
# Epoch 65/250
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 52s 272ms/step - accuracy: 0.8152 - auc: 0.9453 - loss: 0.4453 - precision: 0.8314 - recall: 0.7884 - val_accuracy: 0.7116 - val_auc: 0.8883 - val_loss: 0.6646 - val_precision: 0.7280 - val_recall: 0.6799 - learning_rate: 5.2429e-07

# %% [markdown]
# # PLOTS

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %% [markdown]
# # PR Curve

# %%
valid_labels = []
for xBatch, yBatch in validDataset:
    valid_labels.extend(np.argmax(yBatch, axis=1))
predictions = model.predict(validDataset)
predicted_classes = np.argmax(predictions, axis=1)
yTrue = np.eye(3)[valid_labels]
yPred = predictions
thresholds = {}
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step

# %%
for class_idx in range(3):
    precision, recall, thresholds_pr = precision_recall_curve(yTrue[:, class_idx], yPred[:, class_idx])

    f1_scores = 2 * (precision * recall) / (precision + recall)

    optimal_threshold_pr = thresholds_pr[np.argmax(f1_scores)]
    thresholds[class_idx] = optimal_threshold_pr

    plt.plot(recall, precision, label=f'Class {class_idx} (area = {auc(recall, precision):.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve for each class')
plt.legend(loc="best")
plt.show()

# %%
print("Optimal thresholds for each class (based on maximum F1 score):")
for class_idx, threshold in thresholds.items():
    print(f"Class {class_idx}: {threshold}")
# Out:
# Optimal thresholds for each class (based on maximum F1 score):
# Class 0: 0.37924179434776306
# Class 1: 0.27898791432380676
# Class 2: 0.34087520837783813

# %% [markdown]
# # TESTING

# %%
def customPredict(yPred, thresholds):
    predictions = np.zeros_like(yPred)
    for i in thresholds.keys():
        threshold = thresholds[i]
        predictions[:, i] = (yPred[:, i] >= threshold).astype(int)
    predictions = np.argmax(predictions * yPred, axis=1)
    return predictions

# %%
test_labels = []
for xBatch, yBatch in testDataset:
    test_labels.extend(np.argmax(yBatch, axis=1))
predictions = customPredict(model.predict(testDataset), thresholds)
# predictions = np.argmax(model.predict(testDataset), axis=1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step

# %%
report = classification_report(test_labels, predictions, target_names=categories)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.77      0.67      0.72       126
#   Osteopenia       0.74      0.77      0.75       126
# Osteoporosis       0.69      0.75      0.72       126
#
#     accuracy                           0.73       378
#    macro avg       0.73      0.73      0.73       378
# weighted avg       0.73      0.73      0.73       378

# %%
conf_matrix = confusion_matrix(test_labels, predictions)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=categories,
            yticklabels=categories)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
# Out:
# Text(95.72222222222221, 0.5, 'True Label')

# %%
# runtime.unassign()
